# %% [markdown]
# # 1. Sorri not veri gud in inglish
#
# Have you ever googled someone's name without knowing exactly how it should be written? Were you ever reluctant to look up the correct spelling of a query you typed? Or just unable to type properly because of being in a rush? Modern search engines usually do a pretty good job in deciphering defective user input. In order to be able to do that, a good spell-checking mechanism should be incorporated into a search procedure. Today we will take one step further towards building a good search engine and work on tolerant retrieval with respect to user queries. We will consider two cases:
#
# 1. Users know that they don't know the correct spelling OR they want to get the results that follow some known pattern, so the use so called wildcards - queries like `retr*val`;
# 2. Users don't know the correct spelling OR they don't care OR they are in a rush OR they expect that mistakes will be corrected OR /your option/... so they make mistakes and we need to handle them using:
#
#     2.1. Trigrams with Jaccard coefficient;
#
#     2.2. Simple spellchecker by Peter Norvig with QWERTY weights;

# %% [markdown]
# ## 1.1. Handling wildcards
#
# We will handle wildcard queries using k-grams. K-gram is a list of consecutive k chars in a string - i.e., for the word *'star'*, it will be '*\$st*', '*sta*', '*tar*', and '*ar$*', if we take k=3. Take a look at the [book](https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf)'s *chapter 3.2.2* to understand how k-grams can help efficiently match a wildcard against dictionary words. Here we will only consider wildcards with star symbols (may be multiple).
#
# Notice that for building k-grams index, **we will need a vocabulary of original (correct) word forms** to compare words in user input to the vocabulary of "correct" words (think why inverted index which we built for stemmed words doesn't work here).
#
# You need to implement the following:
#
# - `build_inverted_index_orig_forms` - creates inverted index of original world forms from `facts` list, which is already given to you.
#     Output format: `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#
#
# - `build_k_gram_index` - creates k-gram index which maps every k-gram encountered in facts collection to a list of words containing this k-gram. Use the abovementioned inverted index of original words to construct this index.
#     Output format: `'k_gram': ['word1_with_k_gram', 'word2_with_k_gram', ...]`
#
#
# - `generate_wildcard_options` - produce a list of vocabulary words matching given wildcard by intersecting postings of k-grams present in the wildcard (refer to *ch 3.2.2*).
#
# - `search_wildcard` - return list of facts that contain the words matching a wildcard query.
#
#
# We will use the dataset with curious facts for testing.
#
# ### 1.1.1. Downloading the dataset

# %%
import urllib.request

data_url = "https://raw.githubusercontent.com/IUCVLab/information-retrieval/main/datasets/facts.txt"
local_filename, headers = urllib.request.urlretrieve(data_url)

facts = []
with open(local_filename) as fp:
	for cnt, line in enumerate(fp):
		facts.append(line.strip('\n'))

print(*facts[-5:], sep='\n')
# Out:
# 151. Women have twice as many pain receptors on their body than men. But a much higher pain tolerance.
# 152. There are more stars in space than there are grains of sand on every beach in the world.
# 153. For every human on Earth there are 1.6 million ants.
# 154. The total weight of all those ants, however, is about the same as all the humans.
# 155. On Jupiter and Saturn it rains diamonds.

# %% [markdown]
# ### 1.1.2. Implementation of search

# %%
import re
from collections import Counter, defaultdict
from nltk.corpus import stopwords

import nltk
# nltk.download("stopwords")

def build_inverted_index_orig_forms(documents):
	inverted_index = defaultdict(list)
	s = stopwords.words("english")

	for idx, document in enumerate(documents):
		document = document.lower()

		tokens = (i[0] for i in re.finditer("\w+", document) if i not in s)
		tokens = Counter(tokens)

		for (token, freq) in tokens.items():
			inverted_index[token].append((idx, freq))

	return inverted_index


def k_grams(token, k):
	return (''.join(token[i:i + k]) for i in range(len(token) - k + 1))


def build_k_gram_index(inverted_index, k):
	k_gram_index = defaultdict(set)

	for word in inverted_index.keys():
		padded = "$" + word + "$"
		kgrams = k_grams(padded, k)
		for kgram in kgrams:
			k_gram_index[kgram].add(word)

	return k_gram_index


def generate_wildcard_options(wildcard, k_gram_index, inverted_index):
	pattern = re.compile(wildcard.replace("*", "\w*"))
	wildcard = "$" + wildcard + "$"
	parts = wildcard.split("*")
	
	k = len(next(iter(k_gram_index.keys())))
	kgrams = (gram for part in parts for gram in k_grams(part, k))
	options = set()
	
	for kgram in kgrams:
		options |= set(word for word in k_gram_index[kgram] if pattern.match(word))
	
	return options


def search_wildcard(wildcard, k_gram_index, index, docs):
	#TODO retrive list of documnets (facts) that contain words matching wildcard
	options = generate_wildcard_options(wildcard, k_gram_index, index)
	doc_scores = Counter()
	
	for option in options:
		option_docs = index[option]
		for doc, score in option_docs:
			doc_scores[doc] += score
	
	results = doc_scores.most_common()
	results = [docs[idx] for idx, score in results]
	
	return results

# %%
inverted_idx = build_inverted_index_orig_forms(facts)
inverted_idx
# Out:
# defaultdict(list,
#             {'1': [(0, 1),
#               (10, 1),
#               (87, 1),
#               (98, 1),
#               (131, 1),
#               (132, 1),
#               (137, 1),
#               (156, 1)],
#              'if': [(0, 1),
#               (9, 1),
#               (16, 1),
#               (33, 1),
#               (53, 1),
#               (90, 1),
#               (134, 1),
#               (135, 1),
#               (137, 2),
#               (146, 1)],
#              'you': [(0, 2),
#               (4, 2),
#               (9, 3),
#               (17, 1),
#               (32, 2),
#               (33, 1),
#               (53, 2),
#               (70, 1),
#               (79, 1),
#               (86, 1),
#               (87, 1),
#               (93, 3),
#               (126, 1),
#               (127, 2),
#               (135, 1),
#               (137, 2),
#               (139, 1),
#               (152, 1),
#               (153, 1)],
#              'somehow': [(0, 1)],
#              'found': [(0, 1), (42, 1), (68, 1), (132, 1)],
#              'a': [(0, 2),
#               (2, 1),
#               (7, 2),
#               (9, 1),
#               (10, 1),
#               (11, 1),
#               (13, 1),
#               (14, 1),
#               (19, 3),
#               (22, 1),
#               (23, 1),
#               (25, 1),
#               (27, 1),
#               (30, 2),
#               (31, 2),
#               (33, 1),
#               (34, 1),
#               (36, 1),
#               (38, 1),
#               (42, 1),
#               (46, 1),
#               (48, 1),
#               (49, 2),
#               (53, 2),
#               (54, 1),
#               (56, 1),
#               (58, 2),
#               (59, 1),
#               (61, 1),
#               (63, 1),
#               (64, 1),
#               (65, 1),
#               (66, 2),
#               (68, 2),
#               (77, 2),
#               (79, 1),
#               (81, 1),
#               (82, 1),
#               (83, 2),
#               (91, 1),
#               (94, 2),
#               (98, 2),
#               (102, 2),
#               (105, 1),
#               (109, 1),
#               (115, 1),
#               (116, 1),
#               (119, 1),
#               (120, 2),
#               (123, 4),
#               (125, 2),
#               (126, 2),
#               (127, 1),
#               (128, 2),
#               (134, 1),
#               (135, 1),
#               (137, 3),
#               (143, 1),
#               (144, 2),
#               (145, 1),
#               (149, 1),
#               (150, 1),
#               (154, 1)],
#              'way': [(0, 1), (70, 1), (90, 1)],
#              'to': [(0, 3),
#               (2, 1),
#               (6, 1),
#               (12, 1),
#               (15, 1),
#               (16, 1),
#               (25, 1),
#               (28, 1),
#               (29, 1),
#               (31, 1),
#               (33, 1),
#               (39, 1),
#               (50, 1),
#               (53, 1),
#               (54, 2),
#               (55, 1),
#               (59, 1),
#               (61, 1),
#               (62, 2),
#               (64, 3),
#               (65, 1),
#               (70, 1),
#               (72, 1),
#               (75, 1),
#               (77, 2),
#               (78, 2),
#               (81, 1),
#               (86, 1),
#               (96, 3),
#               (101, 1),
#               (108, 1),
#               (118, 1),
#               (119, 1),
#               (122, 2),
#               (125, 1),
#               (126, 1),
#               (127, 3),
#               (131, 2),
#               (134, 1),
#               (135, 1),
#               (136, 1),
#               (138, 1),
#               (145, 1),
#               (148, 1),
#               (149, 1),
#               (152, 1)],
#              'extract': [(0, 1)],
#              'all': [(0, 2), (48, 1), (90, 1), (97, 1), (145, 2), (157, 2)],
#              'of': [(0, 4),
#               (1, 1),
#               (2, 1),
#               (6, 1),
#               (7, 1),
#               (13, 2),
#               (14, 1),
#               (18, 1),
#               (19, 1),
#               (20, 2),
#               (26, 1),
#               (35, 1),
#               (37, 1),
#               (40, 1),
#               (41, 2),
#               (42, 1),
#               (43, 1),
#               (48, 1),
#               (52, 1),
#               (54, 1),
#               (56, 1),
#               (58, 1),
#               (59, 1),
#               (65, 2),
#               (70, 2),
#               (71, 1),
#               (77, 1),
#               (82, 1),
#               (83, 1),
#               (84, 1),
#               (94, 1),
#               (97, 1),
#               (98, 1),
#               (99, 1),
#               (101, 1),
#               (105, 1),
#               (111, 1),
#               (113, 1),
#               (116, 1),
#               (117, 1),
#               (122, 1),
#               (125, 1),
#               (126, 1),
#               (128, 2),
#               (130, 2),
#               (131, 1),
#               (132, 1),
#               (133, 1),
#               (137, 1),
#               (145, 1),
#               (155, 1),
#               (157, 1)],
#              'the': [(0, 3),
#               (2, 1),
#               (3, 1),
#               (5, 1),
#               (7, 1),
#               (12, 1),
#               (13, 1),
#               (14, 3),
#               (17, 1),
#               (18, 1),
#               (22, 1),
#               (24, 1),
#               (26, 1),
#               (28, 4),
#               (35, 1),
#               (39, 1),
#               (40, 2),
#               (46, 1),
#               (52, 2),
#               (54, 2),
#               (58, 1),
#               (59, 1),
#               (61, 1),
#               (62, 1),
#               (65, 2),
#               (70, 2),
#               (71, 1),
#               (72, 1),
#               (78, 2),
#               (80, 1),
#               (83, 1),
#               (84, 1),
#               (85, 1),
#               (87, 2),
#               (88, 2),
#               (90, 2),
#               (91, 1),
#               (92, 2),
#               (93, 1),
#               (96, 1),
#               (97, 5),
#               (98, 1),
#               (99, 1),
#               (101, 1),
#               (103, 3),
#               (105, 2),
#               (106, 2),
#               (108, 1),
#               (109, 1),
#               (111, 2),
#               (116, 1),
#               (117, 3),
#               (118, 1),
#               (119, 1),
#               (122, 1),
#               (123, 1),
#               (125, 2),
#               (126, 3),
#               (127, 2),
#               (129, 1),
#               (130, 2),
#               (131, 1),
#               (132, 1),
#               (133, 1),
#               (134, 2),
#               (137, 1),
#               (138, 1),
#               (143, 1),
#               (144, 1),
#               (145, 1),
#               (151, 3),
#               (152, 2),
#               (155, 1),
#               (157, 3)],
#              'gold': [(0, 2)],
#              'from': [(0, 1),
#               (21, 1),
#               (32, 1),
#               (40, 1),
#               (58, 1),
#               (64, 1),
#               (65, 1),
#               (69, 1),
#               (75, 1),
#               (85, 1),
#               (89, 1),
#               (104, 1),
#               (117, 1),
#               (126, 1),
#               (127, 3),
#               (130, 1)],
#              'bubbling': [(0, 1)],
#              'core': [(0, 1)],
#              'our': [(0, 1), (8, 1), (85, 2), (130, 1), (132, 1)],
#              'lovely': [(0, 1)],
#              'little': [(0, 1)],
#              'planet': [(0, 1), (5, 1), (8, 1), (91, 1), (129, 1)],
#              'would': [(0, 1),
#               (16, 1),
#               (25, 1),
#               (33, 1),
#               (75, 1),
#               (77, 1),
#               (117, 1),
#               (129, 1),
#               (135, 1)],
#              'be': [(0, 1),
#               (15, 1),
#               (16, 1),
#               (22, 1),
#               (57, 1),
#               (96, 1),
#               (136, 1),
#               (138, 1)],
#              'able': [(0, 1)],
#              'cover': [(0, 1)],
#              'land': [(0, 1)],
#              'in': [(0, 1),
#               (3, 1),
#               (7, 2),
#               (8, 2),
#               (9, 1),
#               (12, 1),
#               (13, 1),
#               (14, 1),
#               (22, 1),
#               (24, 1),
#               (30, 1),
#               (31, 1),
#               (37, 1),
#               (43, 1),
#               (46, 1),
#               (52, 1),
#               (53, 1),
#               (54, 1),
#               (59, 1),
#               (61, 1),
#               (62, 1),
#               (63, 1),
#               (66, 1),
#               (67, 1),
#               (68, 1),
#               (72, 1),
#               (80, 1),
#               (82, 1),
#               (83, 1),
#               (87, 2),
#               (89, 1),
#               (92, 1),
#               (97, 2),
#               (99, 2),
#               (103, 1),
#               (105, 1),
#               (113, 1),
#               (117, 1),
#               (123, 1),
#               (126, 1),
#               (129, 1),
#               (131, 1),
#               (132, 1),
#               (133, 1),
#               (134, 1),
#               (136, 1),
#               (137, 1),
#               (141, 1),
#               (143, 2),
#               (145, 1),
#               (149, 1),
#               (151, 2),
#               (155, 2)],
#              'layer': [(0, 1)],
#              'up': [(0, 1),
#               (39, 1),
#               (62, 1),
#               (81, 1),
#               (82, 1),
#               (122, 1),
#               (125, 1),
#               (127, 1)],
#              'your': [(0, 1),
#               (5, 1),
#               (36, 1),
#               (53, 1),
#               (63, 1),
#               (70, 1),
#               (86, 1),
#               (89, 1),
#               (99, 2),
#               (127, 1),
#               (135, 1),
#               (137, 1),
#               (139, 1),
#               (148, 1),
#               (153, 1)],
#              'knees': [(0, 1)],
#              '2': [(1, 1), (77, 1)],
#              'mcdonalds': [(1, 1)],
#              'calls': [(1, 1), (35, 1)],
#              'frequent': [(1, 1)],
#              'buyers': [(1, 1)],
#              'their': [(1, 1),
#               (2, 1),
#               (6, 1),
#               (73, 1),
#               (75, 3),
#               (111, 1),
#               (113, 1),
#               (114, 2),
#               (119, 2),
#               (154, 1)],
#              'food': [(1, 1),
#               (6, 1),
#               (55, 1),
#               (114, 1),
#               (115, 1),
#               (137, 1),
#               (146, 1)],
#              'heavy': [(1, 1)],
#              'users': [(1, 1), (96, 1)],
#              '3': [(2, 1), (62, 1), (76, 1), (94, 1), (118, 1)],
#              'average': [(2, 1), (11, 1), (14, 1), (79, 1), (138, 1)],
#              'person': [(2, 1),
#               (14, 1),
#               (37, 1),
#               (136, 1),
#               (137, 1),
#               (149, 1)],
#              'spends': [(2, 1)],
#              '6': [(2, 1), (5, 1), (15, 1), (102, 1), (156, 1)],
#              'months': [(2, 1), (144, 1)],
#              'lifetime': [(2, 1), (14, 1), (86, 1)],
#              'waiting': [(2, 1)],
#              'on': [(2, 1),
#               (5, 2),
#               (11, 1),
#               (28, 1),
#               (35, 2),
#               (48, 2),
#               (62, 1),
#               (68, 1),
#               (70, 1),
#               (79, 1),
#               (81, 1),
#               (127, 1),
#               (138, 1),
#               (140, 1),
#               (144, 1),
#               (151, 1),
#               (152, 1),
#               (154, 1),
#               (155, 1),
#               (156, 1),
#               (158, 1)],
#              'red': [(2, 1)],
#              'light': [(2, 1)],
#              'turn': [(2, 1), (127, 1)],
#              'green': [(2, 1), (16, 1)],
#              '4': [(3, 1), (22, 1), (31, 1), (94, 1)],
#              'largest': [(3, 1)],
#              'recorded': [(3, 1)],
#              'snowflake': [(3, 1)],
#              'was': [(3, 2),
#               (7, 1),
#               (34, 1),
#               (46, 1),
#               (59, 1),
#               (66, 1),
#               (106, 1)],
#              'keogh': [(3, 1)],
#              'mt': [(3, 1)],
#              'during': [(3, 1), (59, 1), (86, 1)],
#              'year': [(3, 1),
#               (21, 1),
#               (35, 1),
#               (45, 1),
#               (78, 1),
#               (79, 1),
#               (104, 1),
#               (118, 1)],
#              '1887': [(3, 1)],
#              'and': [(3, 1),
#               (6, 1),
#               (11, 1),
#               (17, 1),
#               (28, 1),
#               (41, 1),
#               (42, 1),
#               (53, 1),
#               (67, 1),
#               (68, 1),
#               (85, 1),
#               (96, 1),
#               (117, 4),
#               (119, 1),
#               (122, 2),
#               (123, 1),
#               (126, 1),
#               (127, 1),
#               (130, 1),
#               (135, 1),
#               (142, 1),
#               (151, 1),
#               (158, 1)],
#              '15': [(3, 1), (14, 1)],
#              'inches': [(3, 1)],
#              'wide': [(3, 1), (31, 1)],
#              '5': [(4, 1), (24, 2), (126, 1), (127, 1), (130, 1)],
#              'burn': [(4, 1)],
#              'more': [(4, 1),
#               (5, 1),
#               (9, 1),
#               (10, 1),
#               (13, 1),
#               (15, 1),
#               (24, 1),
#               (35, 1),
#               (54, 1),
#               (55, 1),
#               (80, 1),
#               (102, 1),
#               (104, 1),
#               (105, 1),
#               (112, 1),
#               (115, 1),
#               (116, 1),
#               (155, 1)],
#              'calories': [(4, 1), (36, 1), (51, 1), (54, 2)],
#              'sleeping': [(4, 1), (11, 1)],
#              'than': [(4, 1),
#               (5, 1),
#               (10, 1),
#               (13, 1),
#               (15, 1),
#               (24, 1),
#               (35, 1),
#               (54, 1),
#               (55, 1),
#               (70, 1),
#               (74, 1),
#               (80, 1),
#               (87, 1),
#               (102, 1),
#               (104, 1),
#               (105, 1),
#               (112, 1),
#               (115, 1),
#               (116, 1),
#               (120, 1),
#               (121, 1),
#               (128, 1),
#               (150, 1),
#               (154, 1),
#               (155, 1)],
#              'do': [(4, 1), (107, 1), (112, 1), (122, 1)],
#              'watching': [(4, 1)],
#              'television': [(4, 1)],
#              'there': [(5, 2),
#               (9, 2),
#               (13, 2),
#               (35, 1),
#               (126, 1),
#               (127, 1),
#               (133, 1),
#               (141, 1),
#               (151, 1),
#               (155, 2),
#               (156, 1)],
#              'are': [(5, 2),
#               (8, 1),
#               (9, 1),
#               (13, 2),
#               (15, 1),
#               (28, 1),
#               (35, 1),
#               (43, 1),
#               (44, 1),
#               (45, 1),
#               (48, 1),
#               (50, 1),
#               (55, 1),
#               (60, 1),
#               (67, 1),
#               (74, 1),
#               (75, 1),
#               (80, 1),
#               (85, 1),
#               (87, 1),
#               (89, 1),
#               (93, 2),
#               (99, 1),
#               (104, 1),
#               (119, 3),
#               (122, 1),
#               (126, 2),
#               (130, 1),
#               (133, 1),
#               (141, 1),
#               (155, 2),
#               (156, 1)],
#              'lifeforms': [(5, 1)],
#              'living': [(5, 1)],
#              'skin': [(5, 1), (6, 1), (89, 1), (108, 1)],
#              'people': [(5, 1),
#               (9, 1),
#               (37, 1),
#               (45, 1),
#               (55, 1),
#               (80, 1),
#               (90, 1),
#               (101, 1),
#               (104, 1),
#               (105, 1),
#               (108, 1),
#               (112, 1)],
#              '7': [(6, 1), (9, 1)],
#              'southern': [(6, 1)],
#              'sea': [(6, 1), (107, 1)],
#              'otters': [(6, 1), (107, 1)],
#              'have': [(6, 1),
#               (76, 1),
#               (77, 1),
#               (93, 1),
#               (101, 1),
#               (105, 1),
#               (113, 1),
#               (122, 1),
#               (126, 1),
#               (130, 1),
#               (132, 1),
#               (144, 1),
#               (154, 1)],
#              'flaps': [(6, 1)],
#              'under': [(6, 1), (84, 1)],
#              'forelegs': [(6, 1)],
#              'that': [(6, 1),
#               (8, 1),
#               (9, 1),
#               (30, 1),
#               (42, 1),
#               (59, 1),
#               (76, 1),
#               (88, 1),
#               (91, 1),
#               (107, 1),
#               (111, 1),
#               (119, 2),
#               (125, 1),
#               (126, 1),
#               (129, 1),
#               (144, 1)],
#              'act': [(6, 1)],
#              'as': [(6, 1),
#               (8, 1),
#               (46, 1),
#               (56, 1),
#               (57, 1),
#               (66, 1),
#               (143, 1),
#               (154, 1),
#               (157, 1)],
#              'pockets': [(6, 1)],
#              'when': [(6, 1), (59, 1), (60, 1), (63, 1), (107, 1), (119, 1)],
#              'diving': [(6, 1)],
#              'they': [(6, 1),
#               (37, 1),
#               (44, 1),
#               (60, 1),
#               (73, 1),
#               (75, 1),
#               (90, 1),
#               (107, 2),
#               (111, 1),
#               (119, 3),
#               (146, 1)],
#              'use': [(6, 1)],
#              'these': [(6, 1)],
#              'pouches': [(6, 1)],
#              'store': [(6, 1)],
#              'rocks': [(6, 1)],
#              '8': [(7, 1), (56, 1), (78, 1), (79, 1), (81, 1)],
#              '1386': [(7, 1)],
#              'pig': [(7, 1)],
#              'france': [(7, 1), (143, 1), (149, 1)],
#              'executed': [(7, 1)],
#              'by': [(7, 1),
#               (15, 1),
#               (45, 1),
#               (66, 1),
#               (78, 1),
#               (84, 1),
#               (93, 1),
#               (137, 2),
#               (139, 1)],
#              'public': [(7, 1), (40, 1)],
#              'hanging': [(7, 1)],
#              'for': [(7, 1),
#               (39, 1),
#               (40, 1),
#               (52, 1),
#               (64, 1),
#               (75, 1),
#               (98, 1),
#               (102, 1),
#               (115, 1),
#               (118, 2),
#               (119, 1),
#               (131, 1),
#               (137, 1),
#               (156, 1)],
#              'murder': [(7, 1)],
#              'child': [(7, 1), (31, 1)],
#              '9': [(8, 1), (18, 1), (43, 1)],
#              'one': [(8, 1),
#               (9, 1),
#               (21, 1),
#               (25, 2),
#               (30, 1),
#               (99, 1),
#               (118, 1),
#               (136, 1),
#               (147, 1),
#               (151, 1)],
#              'every': [(8, 1),
#               (27, 1),
#               (52, 1),
#               (104, 1),
#               (127, 1),
#               (135, 1),
#               (155, 1),
#               (156, 1)],
#              'five': [(8, 1)],
#              'adults': [(8, 1)],
#              'believe': [(8, 1), (9, 1)],
#              'aliens': [(8, 1)],
#              'hiding': [(8, 1)],
#              'disguised': [(8, 1)],
#              'humans': [(8, 1), (157, 1)],
#              '10': [(9, 1),
#               (11, 1),
#               (26, 1),
#               (43, 1),
#               (78, 1),
#               (102, 1),
#               (137, 1)],
#              're': [(9, 1)],
#              'truly': [(9, 1)],
#              'million': [(9, 1),
#               (10, 1),
#               (77, 1),
#               (90, 1),
#               (131, 1),
#               (156, 1)],
#              'still': [(9, 1), (126, 1)],
#              'approximately': [(9, 1), (22, 1)],
#              '184': [(9, 1)],
#              'out': [(9, 1), (20, 1), (33, 1), (38, 1), (43, 1), (127, 1)],
#              'just': [(9, 1), (95, 1), (109, 1), (137, 1)],
#              'like': [(9, 1), (95, 1), (109, 1), (117, 1), (142, 3)],
#              '11': [(10, 1), (42, 1), (51, 1)],
#              'single': [(10, 1), (77, 2)],
#              'cloud': [(10, 1)],
#              'can': [(10, 1),
#               (19, 1),
#               (20, 1),
#               (22, 1),
#               (29, 1),
#               (30, 1),
#               (38, 1),
#               (53, 1),
#               (57, 1),
#               (75, 1),
#               (88, 1),
#               (109, 1),
#               (110, 1),
#               (111, 1),
#               (115, 1),
#               (125, 1),
#               (126, 1),
#               (127, 1),
#               (137, 1),
#               (139, 1),
#               (146, 1),
#               (153, 1)],
#              'weight': [(10, 1), (56, 1), (157, 1)],
#              'pounds': [(10, 1)],
#              '12': [(11, 1), (100, 1), (138, 1)],
#              'human': [(11, 1),
#               (74, 1),
#               (83, 1),
#               (125, 1),
#               (133, 1),
#               (140, 1),
#               (156, 1)],
#              'will': [(11, 1),
#               (22, 1),
#               (32, 1),
#               (44, 1),
#               (49, 2),
#               (56, 1),
#               (86, 1),
#               (94, 1),
#               (128, 1),
#               (136, 1),
#               (138, 1),
#               (144, 1),
#               (146, 1)],
#              'eat': [(11, 1), (54, 1), (75, 1), (146, 1)],
#              '70': [(11, 1), (73, 1)],
#              'assorted': [(11, 1)],
#              'insects': [(11, 1)],
#              'spiders': [(11, 1)],
#              'while': [(11, 1), (32, 1), (153, 1)],
#              '13': [(12, 1)],
#              'james': [(12, 1)],
#              'buchanan': [(12, 1)],
#              '15th': [(12, 1)],
#              'u': [(12, 1), (22, 1), (52, 1), (151, 1)],
#              's': [(12, 1),
#               (18, 1),
#               (22, 1),
#               (26, 1),
#               (29, 1),
#               (31, 1),
#               (33, 1),
#               (34, 1),
#               (35, 1),
#               (46, 1),
#               (52, 1),
#               (54, 1),
#               (55, 1),
#               (96, 1),
#               (108, 1),
#               (111, 1),
#               (117, 1),
#               (121, 1),
#               (129, 1),
#               (137, 1),
#               (145, 1),
#               (151, 2)],
#              'president': [(12, 1)],
#              'continuously': [(12, 1)],
#              'bought': [(12, 1)],
#              'slaves': [(12, 1)],
#              'with': [(12, 1),
#               (54, 2),
#               (75, 1),
#               (93, 1),
#               (96, 1),
#               (102, 1),
#               (114, 1),
#               (130, 1),
#               (135, 1),
#               (147, 1),
#               (148, 1)],
#              'his': [(12, 1), (29, 1), (64, 1)],
#              'own': [(12, 1), (111, 1), (125, 1)],
#              'money': [(12, 1), (29, 1), (135, 1)],
#              'order': [(12, 1)],
#              'free': [(12, 1)],
#              'them': [(12, 1), (59, 1), (131, 1)],
#              '14': [(13, 1)],
#              'possible': [(13, 1)],
#              'iterations': [(13, 1)],
#              'game': [(13, 1)],
#              'chess': [(13, 1)],
#              'atoms': [(13, 1)],
#              'known': [(13, 1), (143, 1)],
#              'universe': [(13, 1), (130, 2)],
#              'walks': [(14, 1)],
#              'equivalent': [(14, 1), (125, 1)],
#              'three': [(14, 1)],
#              'times': [(14, 1),
#               (15, 1),
#               (22, 1),
#               (27, 1),
#               (79, 1),
#               (125, 1),
#               (145, 1)],
#              'around': [(14, 1), (90, 1)],
#              'world': [(14, 1),
#               (18, 1),
#               (26, 1),
#               (105, 1),
#               (143, 1),
#               (155, 1)],
#              '16': [(15, 1), (68, 1)],
#              'men': [(15, 1), (154, 1)],
#              'likely': [(15, 1), (152, 1)],
#              'struck': [(15, 1)],
#              'lightning': [(15, 1), (20, 1)],
#              'women': [(15, 1), (58, 1), (154, 1)],
#              '17': [(16, 1)],
#              'coca': [(16, 1)],
#              'cola': [(16, 1)],
#              'coloring': [(16, 1)],
#              'wasn': [(16, 1)],
#              't': [(16, 1),
#               (29, 1),
#               (38, 1),
#               (59, 1),
#               (69, 1),
#               (88, 1),
#               (96, 1),
#               (124, 1),
#               (139, 1),
#               (146, 1),
#               (153, 1)],
#              'added': [(16, 1)],
#              'it': [(16, 1),
#               (22, 1),
#               (25, 1),
#               (33, 2),
#               (39, 1),
#               (41, 1),
#               (54, 3),
#               (61, 1),
#               (62, 1),
#               (63, 1),
#               (64, 1),
#               (66, 1),
#               (68, 1),
#               (73, 1),
#               (90, 1),
#               (117, 3),
#               (118, 1),
#               (119, 1),
#               (127, 1),
#               (135, 1),
#               (137, 1),
#               (145, 1),
#               (148, 1),
#               (149, 1),
#               (158, 1)],
#              '18': [(17, 1)],
#              'cannot': [(17, 1)],
#              'snore': [(17, 1)],
#              'dream': [(17, 1)],
#              'at': [(17, 1), (81, 1), (145, 1)],
#              'same': [(17, 1), (22, 1), (54, 1), (85, 1), (157, 1)],
#              'time': [(17, 1), (93, 1)],
#              '19': [(18, 1)],
#              'oldest': [(18, 1)],
#              'piece': [(18, 1), (54, 1)],
#              'chewing': [(18, 1), (32, 1), (51, 1)],
#              'gum': [(18, 1), (32, 1), (51, 1)],
#              'is': [(18, 1),
#               (26, 1),
#               (27, 1),
#               (30, 1),
#               (31, 1),
#               (39, 1),
#               (52, 1),
#               (58, 1),
#               (61, 1),
#               (63, 1),
#               (70, 1),
#               (71, 1),
#               (78, 1),
#               (88, 1),
#               (91, 2),
#               (92, 2),
#               (98, 1),
#               (103, 1),
#               (111, 1),
#               (121, 1),
#               (125, 1),
#               (127, 1),
#               (129, 1),
#               (130, 2),
#               (131, 1),
#               (137, 1),
#               (143, 2),
#               (148, 1),
#               (149, 1),
#               (151, 2),
#               (157, 1)],
#              'over': [(18, 1), (59, 1), (76, 1), (80, 1), (132, 1)],
#              '000': [(18, 1),
#               (22, 1),
#               (24, 1),
#               (52, 1),
#               (62, 1),
#               (76, 1),
#               (80, 1),
#               (118, 1),
#               (132, 1),
#               (133, 1)],
#              'years': [(18, 1), (68, 1), (115, 1), (132, 1)],
#              'old': [(18, 1)],
#              '20': [(19, 1), (132, 1)],
#              'coyote': [(19, 1)],
#              'hear': [(19, 1)],
#              'mouse': [(19, 1)],
#              'moving': [(19, 1), (102, 1)],
#              'underneath': [(19, 1)],
#              'foot': [(19, 1), (31, 1)],
#              'snow': [(19, 1)],
#              '21': [(20, 1), (24, 1)],
#              'bolts': [(20, 1)],
#              'shoot': [(20, 1)],
#              'an': [(20, 1),
#               (32, 1),
#               (36, 1),
#               (80, 1),
#               (93, 1),
#               (121, 1),
#               (126, 1),
#               (143, 1),
#               (151, 1)],
#              'erupting': [(20, 1)],
#              'volcano': [(20, 1)],
#              '22': [(21, 1), (25, 1)],
#              'new': [(21, 1), (61, 1), (62, 1)],
#              'york': [(21, 1), (61, 1)],
#              'drifts': [(21, 1)],
#              'about': [(21, 1),
#               (23, 1),
#               (45, 1),
#               (48, 1),
#               (51, 1),
#               (79, 1),
#               (118, 1),
#               (137, 2),
#               (157, 1)],
#              'inch': [(21, 1)],
#              'farther': [(21, 1)],
#              'away': [(21, 1)],
#              'london': [(21, 1)],
#              'each': [(21, 1), (113, 1)],
#              '23': [(22, 1), (26, 1)],
#              'dollar': [(22, 1)],
#              'bill': [(22, 1)],
#              'folded': [(22, 1)],
#              'place': [(22, 1)],
#              'before': [(22, 1), (29, 1), (62, 1), (106, 1)],
#              'tear': [(22, 1)],
#              '24': [(23, 1), (27, 1)],
#              'sneeze': [(23, 1), (53, 1), (148, 1)],
#              'travels': [(23, 1)],
#              '100': [(23, 1), (103, 1), (108, 1)],
#              'miles': [(23, 1), (24, 1), (76, 1), (81, 1), (102, 1), (133, 1)],
#              'per': [(23, 1), (45, 1), (51, 1)],
#              'hour': [(23, 1), (36, 1), (51, 1), (52, 1)],
#              'earth': [(24, 1), (91, 1), (130, 1), (156, 1)],
#              'has': [(24, 1),
#               (54, 2),
#               (83, 1),
#               (95, 1),
#               (97, 1),
#               (108, 1),
#               (134, 1),
#               (150, 1)],
#              'traveled': [(24, 1)],
#              'past': [(24, 1), (132, 1)],
#              'minutes': [(24, 1)],
#              'take': [(25, 1), (127, 1), (135, 1)],
#              'sloth': [(25, 1)],
#              'month': [(25, 1), (137, 1)],
#              'travel': [(25, 1), (76, 1)],
#              'mile': [(25, 1)],
#              'population': [(26, 1), (78, 1)],
#              'left': [(26, 1), (104, 1)],
#              'handed': [(26, 1), (104, 2)],
#              'broken': [(27, 1)],
#              'clock': [(27, 1)],
#              'right': [(27, 1), (80, 1), (104, 1)],
#              'two': [(27, 1), (86, 1), (115, 1), (136, 1)],
#              'day': [(27, 1), (35, 2), (48, 1), (102, 1), (126, 1), (135, 1)],
#              '25': [(28, 1)],
#              'according': [(28, 1)],
#              'amazon': [(28, 1)],
#              'most': [(28, 1), (40, 1), (89, 1), (97, 1), (116, 1)],
#              'highlighted': [(28, 1)],
#              'books': [(28, 1)],
#              'kindle': [(28, 1)],
#              'bible': [(28, 1)],
#              'steve': [(28, 1)],
#              'jobs': [(28, 1)],
#              'biography': [(28, 1)],
#              'hunger': [(28, 1)],
#              'games': [(28, 1)],
#              '26': [(29, 1)],
#              'bob': [(29, 1)],
#              'marley': [(29, 1)],
#              'last': [(29, 1)],
#              'words': [(29, 1), (97, 1), (122, 1)],
#              'son': [(29, 1)],
#              'he': [(29, 1), (34, 1), (69, 1)],
#              'died': [(29, 1)],
#              'were': [(29, 1),
#               (33, 1),
#               (59, 1),
#               (69, 1),
#               (84, 1),
#               (96, 2),
#               (123, 1),
#               (131, 1)],
#              'buy': [(29, 1)],
#              'life': [(29, 1)],
#              '27': [(30, 1), (130, 1), (135, 1)],
#              'mole': [(30, 1)],
#              'dig': [(30, 1)],
#              'tunnel': [(30, 1)],
#              '300': [(30, 1), (93, 1)],
#              'feet': [(30, 1), (33, 1), (99, 1), (114, 1), (145, 1)],
#              'long': [(30, 1), (33, 1), (111, 1), (126, 1)],
#              'only': [(30, 1),
#               (56, 1),
#               (88, 1),
#               (91, 1),
#               (92, 1),
#               (93, 1),
#               (94, 1),
#               (96, 1),
#               (102, 1),
#               (118, 1),
#               (130, 1),
#               (136, 1),
#               (137, 1)],
#              'night': [(30, 1), (81, 1)],
#              '28': [(31, 1)],
#              'hippo': [(31, 1)],
#              'open': [(31, 1), (147, 1), (148, 1)],
#              'mouth': [(31, 1)],
#              'big': [(31, 1)],
#              'enough': [(31, 1), (86, 1), (108, 1), (118, 1), (129, 1)],
#              'fit': [(31, 1)],
#              'tall': [(31, 1), (119, 1)],
#              '29': [(32, 1)],
#              'cut': [(32, 1), (75, 1)],
#              'onion': [(32, 1)],
#              'help': [(32, 1), (134, 1)],
#              'keep': [(32, 1)],
#              'crying': [(32, 1)],
#              '30': [(33, 1), (41, 1)],
#              'stretch': [(33, 1)],
#              'slinky': [(33, 1)],
#              'until': [(33, 1), (44, 1)],
#              'flat': [(33, 1)],
#              'measure': [(33, 1)],
#              '87': [(33, 1), (90, 1)],
#              '31': [(34, 1)],
#              'al': [(34, 1)],
#              'capone': [(34, 1)],
#              'business': [(34, 1)],
#              'card': [(34, 1)],
#              'said': [(34, 1)],
#              'used': [(34, 1), (46, 1), (57, 1)],
#              'furniture': [(34, 1)],
#              'dealer': [(34, 1)],
#              '32': [(35, 1), (113, 1)],
#              'collect': [(35, 1)],
#              'father': [(35, 1)],
#              'any': [(35, 1), (48, 1), (55, 1), (65, 1), (146, 1)],
#              'other': [(35, 1), (55, 1)],
#              '33': [(36, 1), (90, 1)],
#              'banging': [(36, 1)],
#              'head': [(36, 1), (53, 1)],
#              'against': [(36, 1), (126, 1)],
#              'wall': [(36, 1)],
#              'burns': [(36, 1), (51, 1)],
#              '150': [(36, 1), (45, 1), (153, 1)],
#              '34': [(37, 1)],
#              '95': [(37, 1), (98, 1)],
#              'text': [(37, 1)],
#              'things': [(37, 1)],
#              'could': [(37, 1), (90, 1)],
#              'never': [(37, 1), (47, 1), (85, 1), (105, 1)],
#              'say': [(37, 1)],
#              '35': [(38, 1)],
#              'crocodile': [(38, 1)],
#              'poke': [(38, 1)],
#              'its': [(38, 1), (41, 1), (121, 1), (125, 1), (145, 1)],
#              'tongue': [(38, 1), (95, 1), (103, 1), (111, 1), (116, 1)],
#              '36': [(39, 1)],
#              'physically': [(39, 1)],
#              'impossible': [(39, 1), (148, 1)],
#              'pigs': [(39, 1)],
#              'look': [(39, 1), (117, 1)],
#              'into': [(39, 1)],
#              'sky': [(39, 1)],
#              '37': [(40, 1)],
#              'guinness': [(40, 1)],
#              'book': [(40, 2)],
#              'records': [(40, 1)],
#              'holds': [(40, 1)],
#              'record': [(40, 1)],
#              'being': [(40, 1), (75, 1)],
#              'often': [(40, 1)],
#              'stolen': [(40, 1)],
#              'libraries': [(40, 1)],
#              '38': [(41, 1)],
#              'drying': [(41, 1)],
#              'fruit': [(41, 1)],
#              'depletes': [(41, 1)],
#              '80': [(41, 1), (83, 1)],
#              'vitamin': [(41, 1)],
#              'antioxidant': [(41, 1)],
#              'content': [(41, 1)],
#              '39': [(42, 1)],
#              '2010': [(42, 1)],
#              'study': [(42, 1)],
#              '48': [(42, 1), (51, 1)],
#              'soda': [(42, 1)],
#              'fountain': [(42, 1)],
#              'contained': [(42, 2), (65, 1)],
#              'fecal': [(42, 1)],
#              'bacteria': [(42, 1)],
#              'e': [(42, 1)],
#              'coli': [(42, 1)],
#              '40': [(43, 1)],
#              'americans': [(43, 1), (48, 1)],
#              'deficient': [(43, 1)],
#              'potassium': [(43, 1)],
#              '41': [(44, 1)],
#              'blueberries': [(44, 1)],
#              'not': [(44, 1), (49, 1), (91, 1), (107, 1)],
#              'ripen': [(44, 1)],
#              'picked': [(44, 1)],
#              '42': [(45, 1)],
#              'killed': [(45, 1), (52, 1), (104, 1), (126, 1)],
#              'coconuts': [(45, 1)],
#              '43': [(46, 1)],
#              'ketchup': [(46, 1)],
#              'medicine': [(46, 1)],
#              'back': [(46, 1)],
#              '1930': [(46, 1)],
#              '44': [(47, 1)],
#              'honey': [(47, 1), (77, 1)],
#              'spoils': [(47, 1)],
#              '45': [(48, 1)],
#              'half': [(48, 1), (151, 1)],
#              'diet': [(48, 1), (56, 2)],
#              'given': [(48, 1), (138, 1)],
#              '46': [(49, 1)],
#              'hardboiled': [(49, 1)],
#              'egg': [(49, 2)],
#              'spin': [(49, 1)],
#              'but': [(49, 1), (85, 1), (93, 1), (131, 1), (137, 1), (154, 1)],
#              'soft': [(49, 1)],
#              'boiled': [(49, 1)],
#              '47': [(50, 1)],
#              'avocados': [(50, 1)],
#              'poisonous': [(50, 1)],
#              'birds': [(50, 1), (124, 1)],
#              '49': [(52, 1)],
#              'number': [(52, 1)],
#              'animals': [(52, 1)],
#              'meat': [(52, 1)],
#              '500': [(52, 1)],
#              '50': [(53, 1), (105, 1)],
#              'try': [(53, 1)],
#              'suppress': [(53, 1)],
#              'rupture': [(53, 1)],
#              'blood': [(53, 1), (57, 1), (126, 1), (133, 1)],
#              'vessel': [(53, 1)],
#              'or': [(53, 1), (105, 1), (136, 1)],
#              'neck': [(53, 1)],
#              'die': [(53, 1), (75, 1), (127, 1), (137, 1)],
#              '51': [(54, 1)],
#              'celery': [(54, 3)],
#              'negative': [(54, 1)],
#              'takes': [(54, 1), (118, 1)],
#              'begin': [(54, 1), (144, 1)],
#              'apples': [(54, 1), (142, 1)],
#              '52': [(55, 1)],
#              'allergic': [(55, 1)],
#              'cow': [(55, 1)],
#              'milk': [(55, 1)],
#              '53': [(56, 1)],
#              'dieters': [(56, 1)],
#              'follow': [(56, 1)],
#              'restrictive': [(56, 1)],
#              'loss': [(56, 1)],
#              'plan': [(56, 1)],
#              'such': [(56, 1)],
#              'hcg': [(56, 1)],
#              'drops': [(56, 1)],
#              'garcinia': [(56, 1)],
#              'cambogia': [(56, 1)],
#              'etc': [(56, 1)],
#              '54': [(57, 1)],
#              'coconut': [(57, 1)],
#              'water': [(57, 1), (129, 1), (137, 2)],
#              'plasma': [(57, 1)],
#              '55': [(58, 1)],
#              'word': [(58, 2), (97, 2)],
#              'gorilla': [(58, 1)],
#              'derived': [(58, 1)],
#              'greek': [(58, 1)],
#              'meaning': [(58, 1)],
#              'tribe': [(58, 1)],
#              'hairy': [(58, 1)],
#              '56': [(59, 1)],
#              'prisoners': [(59, 1)],
#              'canadian': [(59, 1)],
#              'war': [(59, 2)],
#              'camps': [(59, 1)],
#              'wwii': [(59, 1)],
#              'treated': [(59, 1)],
#              'so': [(59, 1), (107, 1), (111, 1), (119, 1)],
#              'well': [(59, 1)],
#              'lot': [(59, 1)],
#              'didn': [(59, 1), (96, 1)],
#              'want': [(59, 1), (96, 1)],
#              'leave': [(59, 1), (119, 1)],
#              '57': [(60, 1)],
#              'gorillas': [(60, 1), (140, 1)],
#              'burp': [(60, 1)],
#              'happy': [(60, 1)],
#              '58': [(61, 1)],
#              'illegal': [(61, 1)],
#              'sell': [(61, 1), (62, 1), (131, 1)],
#              'haunted': [(61, 1)],
#              'house': [(61, 1), (89, 1), (151, 1)],
#              'without': [(61, 1), (115, 1), (137, 2)],
#              'telling': [(61, 1)],
#              'buyer': [(61, 1)],
#              '59': [(62, 1)],
#              '2006': [(62, 1)],
#              'someone': [(62, 1)],
#              'tried': [(62, 1), (65, 1)],
#              'zealand': [(62, 1)],
#              'ebay': [(62, 2)],
#              'price': [(62, 1)],
#              'got': [(62, 1)],
#              'shut': [(62, 1)],
#              'down': [(62, 1), (82, 1), (84, 1), (117, 1), (131, 1)],
#              '60': [(63, 1), (80, 1), (133, 1)],
#              'considered': [(63, 1), (67, 1)],
#              'good': [(63, 1)],
#              'luck': [(63, 1)],
#              'japan': [(63, 1), (67, 1), (126, 1)],
#              'sumo': [(63, 1)],
#              'wrestler': [(63, 1)],
#              'makes': [(63, 1)],
#              'baby': [(63, 1), (134, 1)],
#              'cry': [(63, 1)],
#              '61': [(64, 1)],
#              'man': [(64, 1)],
#              'britain': [(64, 1)],
#              'changed': [(64, 1)],
#              'name': [(64, 1), (98, 1)],
#              'tim': [(64, 1)],
#              'pppppppppprice': [(64, 1)],
#              'make': [(64, 1), (90, 1)],
#              'harder': [(64, 1), (152, 1)],
#              'telemarketers': [(64, 1)],
#              'pronounce': [(64, 1)],
#              '62': [(65, 1)],
#              'woman': [(65, 1), (68, 1), (134, 1)],
#              'california': [(65, 1)],
#              'once': [(65, 1)],
#              'sue': [(65, 1)],
#              'makers': [(65, 1)],
#              'cap': [(65, 1)],
#              'n': [(65, 1)],
#              'crunch': [(65, 2)],
#              'because': [(65, 1), (69, 1), (73, 1), (75, 1), (96, 1)],
#              'berries': [(65, 2)],
#              'no': [(65, 1), (141, 1)],
#              'kind': [(65, 1)],
#              '63': [(66, 1)],
#              'apple': [(66, 1)],
#              'launched': [(66, 1)],
#              'clothing': [(66, 1)],
#              'line': [(66, 1)],
#              '1986': [(66, 1)],
#              'described': [(66, 1)],
#              'train': [(66, 1)],
#              'wreck': [(66, 1)],
#              'others': [(66, 1)],
#              '64': [(67, 1)],
#              'crooked': [(67, 1)],
#              'teeth': [(67, 1)],
#              'cute': [(67, 1)],
#              'attractive': [(67, 1)],
#              '65': [(68, 1)],
#              'swedish': [(68, 1)],
#              'lost': [(68, 1)],
#              'her': [(68, 2), (134, 1)],
#              'wedding': [(68, 1)],
#              'ring': [(68, 1)],
#              'later': [(68, 1)],
#              'growing': [(68, 1), (85, 1)],
#              'carrot': [(68, 1)],
#              'garden': [(68, 1)],
#              '66': [(69, 1)],
#              'donald': [(69, 1)],
#              'duck': [(69, 1), (123, 1)],
#              'comics': [(69, 1)],
#              'banned': [(69, 1)],
#              'finland': [(69, 1)],
#              'doesn': [(69, 1)],
#              'wear': [(69, 1)],
#              'pants': [(69, 1)],
#              '67': [(70, 1)],
#              'chance': [(70, 2)],
#              'dying': [(70, 1)],
#              'get': [(70, 1)],
#              'lottery': [(70, 1)],
#              'tickets': [(70, 1)],
#              'actually': [(70, 1)],
#              'greater': [(70, 1)],
#              'winning': [(70, 1)],
#              '68': [(71, 1), (130, 1)],
#              'cherophobia': [(71, 1)],
#              'fear': [(71, 1)],
#              'fun': [(71, 1)],
#              '69': [(72, 1)],
#              'toothpaste': [(72, 1)],
#              'colgate': [(72, 1)],
#              'spanish': [(72, 1)],
#              'translates': [(72, 1)],
#              'go': [(72, 1)],
#              'hang': [(72, 1)],
#              'yourself': [(72, 1), (139, 1)],
#              'pirates': [(73, 1)],
#              'wore': [(73, 1)],
#              'earrings': [(73, 1)],
#              'believed': [(73, 1)],
#              'improved': [(73, 1)],
#              'eyesight': [(73, 1)],
#              '71': [(74, 1)],
#              'thigh': [(74, 1)],
#              'bones': [(74, 1), (83, 1), (93, 1), (99, 1)],
#              'stronger': [(74, 1)],
#              'concrete': [(74, 1)],
#              '72': [(75, 1)],
#              'cockroaches': [(75, 1)],
#              'live': [(75, 1), (115, 1), (136, 1), (137, 1)],
#              'several': [(75, 1)],
#              'weeks': [(75, 1)],
#              'heads': [(75, 1), (145, 1)],
#              'off': [(75, 1), (119, 1), (126, 1)],
#              'brains': [(75, 1)],
#              'located': [(75, 1), (99, 1)],
#              'inside': [(75, 1), (111, 1)],
#              'body': [(75, 1),
#               (99, 1),
#               (103, 1),
#               (127, 1),
#               (133, 1),
#               (137, 1),
#               (154, 1)],
#              'eventually': [(75, 1)],
#              'unable': [(75, 1)],
#              '73': [(76, 1)],
#              'scientists': [(76, 1), (132, 1)],
#              'tracked': [(76, 1)],
#              'butterflies': [(76, 1), (114, 1)],
#              '74': [(77, 1)],
#              'produce': [(77, 1), (86, 1)],
#              'pound': [(77, 1)],
#              'bee': [(77, 1)],
#              'visit': [(77, 1)],
#              'flowers': [(77, 1)],
#              '75': [(78, 1)],
#              'expected': [(78, 1)],
#              'rise': [(78, 1)],
#              'billion': [(78, 1), (131, 1), (136, 1)],
#              '2080': [(78, 1)],
#              '76': [(79, 1)],
#              'breathe': [(79, 1)],
#              '409': [(79, 1)],
#              '600': [(79, 1)],
#              '77': [(80, 1)],
#              'flying': [(80, 1)],
#              'united': [(80, 1)],
#              'states': [(80, 1)],
#              'airplane': [(80, 1)],
#              'now': [(80, 1), (131, 1)],
#              '78': [(81, 1)],
#              'hamsters': [(81, 1)],
#              'run': [(81, 1), (97, 1)],
#              'wheel': [(81, 1)],
#              '79': [(82, 1)],
#              'waterfall': [(82, 1)],
#              'hawaii': [(82, 1)],
#              'goes': [(82, 1)],
#              'sometimes': [(82, 1)],
#              'instead': [(82, 1)],
#              'church': [(83, 1)],
#              'czech': [(83, 1)],
#              'republic': [(83, 1)],
#              'chandelier': [(83, 1)],
#              'made': [(83, 1), (89, 1), (105, 1), (126, 1)],
#              'entirely': [(83, 1)],
#              '81': [(84, 1)],
#              'code': [(84, 1)],
#              'hammurabi': [(84, 1)],
#              'bartenders': [(84, 1)],
#              'who': [(84, 1), (96, 1)],
#              'watered': [(84, 1)],
#              'beer': [(84, 1)],
#              'punished': [(84, 1)],
#              'execution': [(84, 1)],
#              '82': [(85, 1)],
#              'eyes': [(85, 1), (145, 1), (148, 1)],
#              'always': [(85, 1), (144, 1)],
#              'size': [(85, 1)],
#              'birth': [(85, 1), (140, 1)],
#              'nose': [(85, 1), (153, 1)],
#              'ears': [(85, 1), (113, 1)],
#              'stop': [(85, 1)],
#              '83': [(86, 1)],
#              'saliva': [(86, 1)],
#              'fill': [(86, 1)],
#              'swimming': [(86, 1)],
#              'pools': [(86, 1)],
#              '84': [(87, 1)],
#              'shorter': [(87, 1)],
#              'evening': [(87, 1)],
#              'morning': [(87, 1)],
#              '85': [(88, 1)],
#              'elephant': [(88, 1)],
#              'mammal': [(88, 1)],
#              'jump': [(88, 1), (125, 1)],
#              '86': [(89, 1)],
#              'dust': [(89, 1)],
#              'particles': [(89, 1)],
#              'dead': [(89, 1), (149, 1)],
#              'held': [(90, 1)],
#              'hands': [(90, 1), (107, 1)],
#              'equator': [(90, 1)],
#              '88': [(91, 1)],
#              'named': [(91, 1)],
#              'after': [(91, 1), (126, 1)],
#              'god': [(91, 1)],
#              '89': [(92, 1)],
#              'bloodhound': [(92, 1)],
#              'animal': [(92, 1)],
#              'whose': [(92, 1), (127, 1)],
#              'evidence': [(92, 1)],
#              'admissible': [(92, 1)],
#              'court': [(92, 1)],
#              '90': [(93, 1)],
#              'born': [(93, 1)],
#              'adult': [(93, 1)],
#              '206': [(93, 1)],
#              '91': [(94, 1)],
#              'ten': [(94, 1)],
#              'gallon': [(94, 2)],
#              'hat': [(94, 1)],
#              'hold': [(94, 1), (107, 1), (126, 1)],
#              '92': [(95, 1)],
#              'fingerprints': [(95, 1)],
#              'everyone': [(95, 1)],
#              'different': [(95, 1)],
#              'prints': [(95, 1)],
#              '93': [(96, 1)],
#              'atm': [(96, 1)],
#              'originally': [(96, 1)],
#              'thought': [(96, 1)],
#              'failures': [(96, 1)],
#              'prostitutes': [(96, 1)],
#              'gamblers': [(96, 1)],
#              'deal': [(96, 1)],
#              'tellers': [(96, 1)],
#              'face': [(96, 2)],
#              '94': [(97, 1)],
#              'english': [(97, 1), (143, 2)],
#              'language': [(97, 1)],
#              'set': [(97, 1)],
#              'definitions': [(97, 1)],
#              'comes': [(97, 1), (117, 1)],
#              'close': [(97, 1)],
#              'second': [(97, 1), (98, 1)],
#              'jiffy': [(98, 1)],
#              'scientific': [(98, 1)],
#              '100th': [(98, 1)],
#              '96': [(99, 1)],
#              'fourth': [(99, 1)],
#              '97': [(100, 1)],
#              '111': [(100, 6), (114, 1)],
#              'x': [(100, 1)],
#              '345': [(100, 1)],
#              '678': [(100, 1)],
#              '987': [(100, 1)],
#              '654': [(100, 1)],
#              '321': [(100, 1)],
#              '98': [(101, 1)],
#              'blue': [(101, 1), (116, 1), (127, 1)],
#              'eyed': [(101, 1)],
#              'tend': [(101, 1)],
#              'highest': [(101, 1)],
#              'tolerance': [(101, 1), (154, 1)],
#              'alcohol': [(101, 1)],
#              '99': [(102, 1)],
#              'traffic': [(102, 1)],
#              'jam': [(102, 1)],
#              'lasted': [(102, 1)],
#              'days': [(102, 1), (127, 1), (135, 1)],
#              'cars': [(102, 1)],
#              '0': [(102, 1), (135, 1)],
#              'strongest': [(103, 1)],
#              'muscle': [(103, 1)],
#              '101': [(104, 1)],
#              '2500': [(104, 1)],
#              'using': [(104, 1)],
#              'products': [(104, 1)],
#              '102': [(105, 1)],
#              'received': [(105, 1)],
#              'telephone': [(105, 1)],
#              'call': [(105, 1)],
#              '103': [(106, 1)],
#              'cigarette': [(106, 1)],
#              'lighter': [(106, 1)],
#              'invented': [(106, 1)],
#              'match': [(106, 1)],
#              '104': [(107, 1)],
#              'sleep': [(107, 1), (147, 1)],
#              'drift': [(107, 1)],
#              'apart': [(107, 1)],
#              '105': [(108, 1)],
#              'golden': [(108, 1)],
#              'poison': [(108, 1)],
#              'dart': [(108, 1)],
#              'frog': [(108, 1)],
#              'toxins': [(108, 1)],
#              'kill': [(108, 1), (112, 1), (139, 1)],
#              '106': [(109, 1)],
#              'male': [(109, 1), (119, 1)],
#              'ostrich': [(109, 1), (121, 1)],
#              'roar': [(109, 1)],
#              'lion': [(109, 1)],
#              '107': [(110, 1)],
#              'mountain': [(110, 1)],
#              'lions': [(110, 1)],
#              'whistle': [(110, 1)],
#              '108': [(111, 1)],
#              'giraffe': [(111, 1)],
#              'lick': [(111, 1)],
#              'ear': [(111, 1)],
#              '109': [(112, 1)],
#              'cows': [(112, 1), (118, 1)],
#              'sharks': [(112, 1)],
#              '110': [(113, 1)],
#              'cats': [(113, 1), (117, 3)],
#              'muscles': [(113, 1)],
#              'taste': [(114, 1), (142, 1)],
#              '112': [(115, 1)],
#              'tarantula': [(115, 1)],
#              '113': [(116, 1)],
#              'whale': [(116, 1)],
#              'weighs': [(116, 1), (120, 1)],
#              'elephants': [(116, 1)],
#              '114': [(117, 1)],
#              'ever': [(117, 1)],
#              'wonder': [(117, 1)],
#              'where': [(117, 1), (126, 1), (151, 1)],
#              'phrase': [(117, 1)],
#              'raining': [(117, 1)],
#              'dogs': [(117, 3), (119, 1), (122, 1)],
#              '17th': [(117, 1)],
#              'century': [(117, 1)],
#              'many': [(117, 1), (154, 1)],
#              'homeless': [(117, 1)],
#              'drown': [(117, 1)],
#              'float': [(117, 1), (129, 1)],
#              'streets': [(117, 1)],
#              'england': [(117, 1)],
#              'making': [(117, 1)],
#              'literally': [(117, 1)],
#              'rained': [(117, 1)],
#              '115': [(118, 1)],
#              'supply': [(118, 1)],
#              'leather': [(118, 1)],
#              'nfl': [(118, 1)],
#              '116': [(119, 1), (136, 1)],
#              'lift': [(119, 1)],
#              'legs': [(119, 1)],
#              'urinating': [(119, 1)],
#              'reason': [(119, 1)],
#              'trying': [(119, 1)],
#              'mark': [(119, 1)],
#              'higher': [(119, 1), (128, 1), (154, 1)],
#              'gives': [(119, 1)],
#              'message': [(119, 1)],
#              'intimidating': [(119, 1)],
#              '117': [(120, 1)],
#              'hummingbird': [(120, 1)],
#              'less': [(120, 1), (152, 1)],
#              'penny': [(120, 1)],
#              '118': [(121, 1)],
#              'eye': [(121, 1), (147, 1)],
#              'bigger': [(121, 1)],
#              'brain': [(121, 1)],
#              '119': [(122, 1)],
#              'capable': [(122, 1)],
#              'understanding': [(122, 1)],
#              '250': [(122, 1)],
#              'gestures': [(122, 1)],
#              'demonstrated': [(122, 1)],
#              'ability': [(122, 1)],
#              'simple': [(122, 1)],
#              'mathematical': [(122, 1)],
#              'calculations': [(122, 1)],
#              '120': [(123, 1)],
#              'sheep': [(123, 1)],
#              'rooster': [(123, 1)],
#              'first': [(123, 1)],
#              'passengers': [(123, 1)],
#              'hot': [(123, 1)],
#              'air': [(123, 1)],
#              'balloon': [(123, 1)],
#              '121': [(124, 1)],
#              'don': [(124, 1)],
#              'urinate': [(124, 1)],
#              '122': [(125, 1)],
#              'flea': [(125, 1)],
#              '200': [(125, 1)],
#              'height': [(125, 1)],
#              'jumping': [(125, 1)],
#              'empire': [(125, 1)],
#              'state': [(125, 1)],
#              'building': [(125, 1)],
#              '123': [(126, 1)],
#              'temples': [(126, 1)],
#              'kyoto': [(126, 1)],
#              'stained': [(126, 1)],
#              'ceilings': [(126, 2)],
#              'floorboards': [(126, 1)],
#              'castle': [(126, 1)],
#              'warriors': [(126, 1)],
#              'themselves': [(126, 1), (146, 1)],
#              'army': [(126, 1)],
#              'this': [(126, 1), (130, 1)],
#              'see': [(126, 1), (145, 1)],
#              'outlines': [(126, 1)],
#              'footprints': [(126, 1)],
#              '124': [(127, 1)],
#              'snake': [(127, 1)],
#              'called': [(127, 1), (143, 1)],
#              'boomslang': [(127, 1)],
#              'venom': [(127, 1)],
#              'causes': [(127, 1)],
#              'bleed': [(127, 1)],
#              'orifice': [(127, 1)],
#              'may': [(127, 1)],
#              'even': [(127, 1), (130, 1)],
#              'internal': [(127, 1)],
#              'bleeding': [(127, 2)],
#              '125': [(128, 1)],
#              'ball': [(128, 2)],
#              'glass': [(128, 1)],
#              'bounce': [(128, 1)],
#              'rubber': [(128, 1)],
#              '126': [(129, 1)],
#              'saturn': [(129, 1), (158, 1)],
#              'density': [(129, 1)],
#              'low': [(129, 1)],
#              '127': [(130, 1)],
#              'dark': [(130, 2)],
#              'energy': [(130, 1)],
#              'matter': [(130, 1)],
#              'both': [(130, 1)],
#              'invisible': [(130, 1)],
#              'powerful': [(130, 1)],
#              'telescopes': [(130, 1)],
#              'means': [(130, 1)],
#              'we': [(130, 1)],
#              'seen': [(130, 1)],
#              '128': [(131, 1)],
#              'founders': [(131, 1)],
#              'google': [(131, 3)],
#              'willing': [(131, 1)],
#              'excite': [(131, 2)],
#              '1999': [(131, 1)],
#              'turned': [(131, 1)],
#              'worth': [(131, 1)],
#              '527': [(131, 1)],
#              '129': [(132, 1)],
#              'planets': [(132, 1)],
#              'outside': [(132, 1)],
#              'solar': [(132, 1)],
#              'system': [(132, 1)],
#              '130': [(133, 1)],
#              'vessels': [(133, 1)],
#              '131': [(134, 1)],
#              'pregnant': [(134, 1)],
#              'organ': [(134, 2)],
#              'damage': [(134, 1)],
#              'womb': [(134, 1)],
#              'sends': [(134, 1)],
#              'stem': [(134, 1)],
#              'cells': [(134, 1)],
#              'repair': [(134, 1)],
#              '132': [(135, 1)],
#              'started': [(135, 1)],
#              '01': [(135, 1)],
#              'doubled': [(135, 1)],
#              'become': [(135, 1)],
#              'millionaire': [(135, 1)],
#              '133': [(136, 1)],
#              'older': [(136, 1)],
#              '134': [(137, 1)],
#              'week': [(137, 1)],
#              'amount': [(137, 1)],
#              'reduced': [(137, 2)],
#              'll': [(137, 2)],
#              'feel': [(137, 1)],
#              'thirsty': [(137, 1)],
#              '135': [(138, 1)],
#              'newborns': [(138, 1)],
#              'wrong': [(138, 1)],
#              'parents': [(138, 1)],
#              'daily': [(138, 1)],
#              '136': [(139, 1)],
#              'holding': [(139, 1), (153, 1)],
#              'breath': [(139, 1)],
#              '137': [(140, 1)],
#              'control': [(140, 1)],
#              'pills': [(140, 1)],
#              'work': [(140, 1)],
#              '138': [(141, 1)],
#              'clocks': [(141, 1)],
#              'las': [(141, 1)],
#              'vegas': [(141, 1)],
#              'gambling': [(141, 1)],
#              'casinos': [(141, 1)],
#              '139': [(142, 1)],
#              'beetles': [(142, 1)],
#              'wasps': [(142, 1)],
#              'pine': [(142, 1)],
#              'nuts': [(142, 1)],
#              'worms': [(142, 1), (146, 1)],
#              'fried': [(142, 1)],
#              ...})

# %%
list(k_grams("$asdef$", 3))
# Out:
# ['$as', 'asd', 'sde', 'def', 'ef$']

# %%
kgram_idx = build_k_gram_index(inverted_idx, 3)
kgram_idx
# Out:
# defaultdict(set,
#             {'$1$': {'1'},
#              '$if': {'if'},
#              'if$': {'if'},
#              '$yo': {'york', 'you', 'your', 'yourself'},
#              'you': {'you', 'your', 'yourself'},
#              'ou$': {'you'},
#              '$so': {'so',
#               'soda',
#               'soft',
#               'solar',
#               'some',
#               'somehow',
#               'someone',
#               'sometimes',
#               'son',
#               'southern'},
#              'som': {'some', 'somehow', 'someone', 'sometimes'},
#              'ome': {'become',
#               'comes',
#               'homeless',
#               'some',
#               'somehow',
#               'someone',
#               'sometimes',
#               'women'},
#              'meh': {'somehow'},
#              'eho': {'somehow'},
#              'how': {'however', 'somehow'},
#              'ow$': {'cow', 'follow', 'low', 'now', 'snow', 'somehow'},
#              '$fo': {'folded',
#               'follow',
#               'food',
#               'foot',
#               'footprints',
#               'for',
#               'forelegs',
#               'found',
#               'founders',
#               'fountain',
#               'four',
#               'fourth'},
#              'fou': {'found', 'founders', 'fountain', 'four', 'fourth'},
#              'oun': {'amount',
#               'around',
#               'bloodhound',
#               'bounce',
#               'country',
#               'found',
#               'founders',
#               'fountain',
#               'mountain',
#               'pound',
#               'pounds',
#               'pronounce'},
#              'und': {'around',
#               'bloodhound',
#               'found',
#               'founders',
#               'pound',
#               'pounds',
#               'sunday',
#               'under',
#               'underneath',
#               'understanding'},
#              'nd$': {'and',
#               'around',
#               'bloodhound',
#               'england',
#               'find',
#               'finland',
#               'found',
#               'kind',
#               'land',
#               'pound',
#               'sand',
#               'second',
#               'tend',
#               'zealand'},
#              '$a$': {'a'},
#              '$wa': {'waiting',
#               'walks',
#               'wall',
#               'want',
#               'war',
#               'warriors',
#               'was',
#               'wasn',
#               'wasps',
#               'watching',
#               'water',
#               'watered',
#               'waterfall',
#               'way'},
#              'way': {'always', 'away', 'way'},
#              'ay$': {'away',
#               'day',
#               'ebay',
#               'friday',
#               'may',
#               'say',
#               'sunday',
#               'way'},
#              '$to': {'to',
#               'tolerance',
#               'tongue',
#               'toothpaste',
#               'total',
#               'toxins'},
#              'to$': {'into', 'kyoto', 'pluto', 'to'},
#              '$ex': {'excite', 'executed', 'execution', 'expected', 'extract'},
#              'ext': {'extract', 'text'},
#              'xtr': {'extract'},
#              'tra': {'attractive',
#               'concentrate',
#               'demonstrated',
#               'extract',
#               'tracked',
#               'traffic',
#               'train',
#               'translates',
#               'travel',
#               'traveled',
#               'travels'},
#              'rac': {'attractive', 'extract', 'tracked'},
#              'act': {'act', 'actually', 'attractive', 'bacteria', 'extract'},
#              'ct$': {'act', 'collect', 'extract'},
#              '$al': {'al', 'alcohol', 'aliens', 'all', 'allergic', 'always'},
#              'all': {'actually',
#               'all',
#               'allergic',
#               'ball',
#               'balloon',
#               'call',
#               'called',
#               'calls',
#               'eventually',
#               'fall',
#               'falling',
#               'gallon',
#               'literally',
#               'originally',
#               'physically',
#               'tall',
#               'wall',
#               'waterfall'},
#              'll$': {'all',
#               'ball',
#               'bill',
#               'call',
#               'fall',
#               'fill',
#               'kill',
#               'll',
#               'sell',
#               'still',
#               'tall',
#               'wall',
#               'waterfall',
#               'well',
#               'will'},
#              '$of': {'of', 'off', 'often'},
#              'of$': {'of'},
#              '$th': {'than',
#               'that',
#               'the',
#               'their',
#               'them',
#               'themselves',
#               'there',
#               'these',
#               'they',
#               'thigh',
#               'things',
#               'thirsty',
#               'this',
#               'those',
#               'thought',
#               'three'},
#              'the': {'another',
#               'breathe',
#               'farther',
#               'father',
#               'leather',
#               'mathematical',
#               'other',
#               'others',
#               'southern',
#               'the',
#               'their',
#               'them',
#               'themselves',
#               'there',
#               'these',
#               'they'},
#              'he$': {'breathe', 'he', 'the'},
#              '$go': {'go',
#               'god',
#               'goes',
#               'gold',
#               'golden',
#               'good',
#               'google',
#               'gorilla',
#               'gorillas',
#               'got'},
#              'gol': {'gold', 'golden'},
#              'old': {'folded',
#               'gold',
#               'golden',
#               'hold',
#               'holding',
#               'holds',
#               'old',
#               'older',
#               'oldest'},
#              'ld$': {'child',
#               'could',
#               'donald',
#               'gold',
#               'held',
#               'hold',
#               'old',
#               'world',
#               'would'},
#              '$fr': {'france',
#               'free',
#               'french',
#               'frequent',
#               'friday',
#               'fried',
#               'frog',
#               'from',
#               'fruit'},
#              'fro': {'frog', 'from'},
#              'rom': {'from'},
#              'om$': {'from', 'venom'},
#              '$bu': {'bubbling',
#               'buchanan',
#               'building',
#               'burn',
#               'burns',
#               'burp',
#               'business',
#               'but',
#               'butterflies',
#               'buy',
#               'buyer',
#               'buyers'},
#              'bub': {'bubbling'},
#              'ubb': {'bubbling', 'rubber'},
#              'bbl': {'bubbling'},
#              'bli': {'bubbling', 'gambling', 'public', 'republic'},
#              'lin': {'bubbling',
#               'ceilings',
#               'falling',
#               'gambling',
#               'line',
#               'outlines',
#               'slinky',
#               'telling',
#               'willing'},
#              'ing': {'according',
#               'banging',
#               'being',
#               'bleeding',
#               'bubbling',
#               'building',
#               'ceilings',
#               'chewing',
#               'clothing',
#               'coloring',
#               'crying',
#               'diving',
#               'drying',
#               'during',
#               'dying',
#               'earrings',
#               'erupting',
#               'evening',
#               'falling',
#               'fingerprints',
#               'flying',
#               'gambling',
#               'growing',
#               'hanging',
#               'hiding',
#               'holding',
#               'hummingbird',
#               'intimidating',
#               'jumping',
#               'lightning',
#               'living',
#               'making',
#               'meaning',
#               'morning',
#               'moving',
#               'raining',
#               'ring',
#               'single',
#               'sleeping',
#               'speaking',
#               'swimming',
#               'telling',
#               'things',
#               'trying',
#               'understanding',
#               'urinating',
#               'using',
#               'waiting',
#               'watching',
#               'wedding',
#               'willing',
#               'winning'},
#              'ng$': {'according',
#               'banging',
#               'being',
#               'bleeding',
#               'boomslang',
#               'bubbling',
#               'building',
#               'chewing',
#               'clothing',
#               'coloring',
#               'crying',
#               'diving',
#               'drying',
#               'during',
#               'dying',
#               'erupting',
#               'evening',
#               'falling',
#               'flying',
#               'gambling',
#               'growing',
#               'hang',
#               'hanging',
#               'hiding',
#               'holding',
#               'intimidating',
#               'jumping',
#               'lightning',
#               'living',
#               'long',
#               'making',
#               'meaning',
#               'morning',
#               'moving',
#               'raining',
#               'ring',
#               'sleeping',
#               'speaking',
#               'swimming',
#               'telling',
#               'trying',
#               'understanding',
#               'urinating',
#               'using',
#               'waiting',
#               'watching',
#               'wedding',
#               'willing',
#               'winning',
#               'wrong'},
#              '$co': {'coca',
#               'cockroaches',
#               'coconut',
#               'coconuts',
#               'code',
#               'cola',
#               'colgate',
#               'coli',
#               'collect',
#               'coloring',
#               'comes',
#               'comics',
#               'concentrate',
#               'concrete',
#               'considered',
#               'contained',
#               'content',
#               'continuously',
#               'control',
#               'core',
#               'could',
#               'country',
#               'court',
#               'cover',
#               'cow',
#               'cows',
#               'coyote'},
#              'cor': {'according', 'core', 'record', 'recorded', 'records'},
#              'ore': {'before',
#               'core',
#               'forelegs',
#               'more',
#               'snore',
#               'store',
#               'wore'},
#              're$': {'are',
#               'before',
#               'core',
#               'empire',
#               'furniture',
#               'measure',
#               'millionaire',
#               'more',
#               're',
#               'rupture',
#               'snore',
#               'store',
#               'there',
#               'were',
#               'where',
#               'wore'},
#              '$ou': {'our', 'out', 'outlines', 'outside'},
#              'our': {'court',
#               'four',
#               'fourth',
#               'hour',
#               'our',
#               'your',
#               'yourself'},
#              'ur$': {'four', 'hour', 'our', 'your'},
#              '$lo': {'located',
#               'london',
#               'long',
#               'look',
#               'loss',
#               'lost',
#               'lot',
#               'lottery',
#               'lovely',
#               'low'},
#              'lov': {'lovely'},
#              'ove': {'cover', 'improved', 'lovely', 'over'},
#              'vel': {'lovely', 'travel', 'traveled', 'travels'},
#              'ely': {'approximately', 'entirely', 'likely', 'lovely'},
#              'ly$': {'actually',
#               'approximately',
#               'continuously',
#               'daily',
#               'entirely',
#               'eventually',
#               'likely',
#               'literally',
#               'lovely',
#               'only',
#               'originally',
#               'physically',
#               'supply',
#               'truly'},
#              '$li': {'libraries',
#               'lick',
#               'life',
#               'lifeforms',
#               'lifetime',
#               'lift',
#               'light',
#               'lighter',
#               'lightning',
#               'like',
#               'likely',
#               'line',
#               'lion',
#               'lions',
#               'literally',
#               'little',
#               'live',
#               'living'},
#              'lit': {'ability', 'literally', 'little'},
#              'itt': {'little'},
#              'ttl': {'little'},
#              'tle': {'beetles', 'castle', 'little', 'whistle', 'wrestler'},
#              'le$': {'able',
#               'admissible',
#               'apple',
#               'bible',
#               'capable',
#               'castle',
#               'crocodile',
#               'google',
#               'impossible',
#               'invisible',
#               'kindle',
#               'little',
#               'male',
#               'mile',
#               'mole',
#               'muscle',
#               'people',
#               'possible',
#               'simple',
#               'single',
#               'unable',
#               'whale',
#               'while',
#               'whistle'},
#              '$pl': {'place',
#               'placement',
#               'plan',
#               'planet',
#               'planets',
#               'plasma',
#               'pluto'},
#              'pla': {'airplane',
#               'place',
#               'placement',
#               'plan',
#               'planet',
#               'planets',
#               'plasma'},
#              'lan': {'airplane',
#               'boomslang',
#               'england',
#               'finland',
#               'land',
#               'language',
#               'plan',
#               'planet',
#               'planets',
#               'zealand'},
#              'ane': {'airplane', 'planet', 'planets'},
#              'net': {'planet', 'planets'},
#              'et$': {'diet', 'feet', 'get', 'planet', 'set'},
#              '$wo': {'woman',
#               'womb',
#               'women',
#               'wonder',
#               'word',
#               'words',
#               'wore',
#               'work',
#               'world',
#               'worms',
#               'worth',
#               'would'},
#              'wou': {'would'},
#              'oul': {'could', 'would'},
#              'uld': {'could', 'would'},
#              '$be': {'be',
#               'beach',
#               'because',
#               'become',
#               'bee',
#               'beer',
#               'beetles',
#               'before',
#               'begin',
#               'being',
#               'believe',
#               'believed',
#               'berries'},
#              'be$': {'be', 'tribe'},
#              '$ab': {'ability', 'able', 'about'},
#              'abl': {'able', 'capable', 'enables', 'unable'},
#              'ble': {'able',
#               'admissible',
#               'bible',
#               'bleed',
#               'bleeding',
#               'capable',
#               'doubled',
#               'enables',
#               'gamblers',
#               'impossible',
#               'invisible',
#               'possible',
#               'unable'},
#              'cov': {'cover'},
#              'ver': {'average',
#               'cover',
#               'ever',
#               'every',
#               'everyone',
#               'however',
#               'never',
#               'over',
#               'several',
#               'universe'},
#              'er$': {'after',
#               'another',
#               'beer',
#               'bigger',
#               'border',
#               'buyer',
#               'chandelier',
#               'cover',
#               'dealer',
#               'ever',
#               'farther',
#               'father',
#               'greater',
#               'harder',
#               'her',
#               'higher',
#               'however',
#               'hunger',
#               'jupiter',
#               'larger',
#               'later',
#               'layer',
#               'leather',
#               'lighter',
#               'matter',
#               'murder',
#               'never',
#               'number',
#               'older',
#               'order',
#               'other',
#               'over',
#               'per',
#               'rooster',
#               'rubber',
#               'shorter',
#               'stronger',
#               'under',
#               'water',
#               'wonder',
#               'wrestler'},
#              '$la': {'land',
#               'language',
#               'larger',
#               'largest',
#               'las',
#               'last',
#               'lasted',
#               'later',
#               'launched',
#               'layer'},
#              'and': {'and',
#               'chandelier',
#               'england',
#               'finland',
#               'handed',
#               'hands',
#               'land',
#               'sand',
#               'understanding',
#               'zealand'},
#              '$in': {'in',
#               'inch',
#               'inches',
#               'insects',
#               'inside',
#               'instead',
#               'internal',
#               'intimidating',
#               'into',
#               'invented',
#               'invisible'},
#              'in$': {'begin',
#               'brain',
#               'britain',
#               'fountain',
#               'in',
#               'mountain',
#               'pain',
#               'skin',
#               'spin',
#               'train',
#               'vitamin'},
#              'lay': {'layer'},
#              'aye': {'layer'},
#              'yer': {'buyer', 'buyers', 'layer'},
#              '$up': {'up'},
#              'up$': {'ketchup', 'up'},
#              '$kn': {'knees', 'known'},
#              'kne': {'knees'},
#              'nee': {'knees', 'sneeze'},
#              'ees': {'knees'},
#              'es$': {'apples',
#               'beetles',
#               'berries',
#               'blueberries',
#               'bones',
#               'butterflies',
#               'calories',
#               'causes',
#               'cockroaches',
#               'comes',
#               'depletes',
#               'enables',
#               'eyes',
#               'failures',
#               'games',
#               'gestures',
#               'gives',
#               'goes',
#               'inches',
#               'james',
#               'knees',
#               'libraries',
#               'makes',
#               'miles',
#               'minutes',
#               'muscles',
#               'outlines',
#               'particles',
#               'pirates',
#               'pouches',
#               'prostitutes',
#               'slaves',
#               'sometimes',
#               'states',
#               'takes',
#               'telescopes',
#               'temples',
#               'themselves',
#               'times',
#               'translates'},
#              '$2$': {'2'},
#              '$mc': {'mcdonalds'},
#              'mcd': {'mcdonalds'},
#              'cdo': {'mcdonalds'},
#              'don': {'don', 'donald', 'donkey', 'london', 'mcdonalds'},
#              'ona': {'donald', 'mcdonalds', 'millionaire'},
#              'nal': {'donald', 'internal', 'mcdonalds', 'originally'},
#              'ald': {'donald', 'mcdonalds'},
#              'lds': {'holds', 'mcdonalds'},
#              'ds$': {'birds',
#               'diamonds',
#               'floorboards',
#               'hands',
#               'heads',
#               'holds',
#               'mcdonalds',
#               'pounds',
#               'records',
#               'sends',
#               'spends',
#               'words'},
#              '$ca': {'calculations',
#               'california',
#               'call',
#               'called',
#               'calls',
#               'calories',
#               'cambogia',
#               'camps',
#               'can',
#               'canada',
#               'canadian',
#               'cannot',
#               'cap',
#               'capable',
#               'capone',
#               'card',
#               'carrot',
#               'cars',
#               'casinos',
#               'castle',
#               'cats',
#               'causes'},
#              'cal': {'calculations',
#               'california',
#               'call',
#               'called',
#               'calls',
#               'calories',
#               'fecal',
#               'mathematical',
#               'physically'},
#              'lls': {'calls', 'cells', 'pills'},
#              'ls$': {'animals',
#               'calls',
#               'cells',
#               'pills',
#               'pools',
#               'spoils',
#               'travels',
#               'vessels'},
#              'fre': {'free', 'french', 'frequent'},
#              'req': {'frequent'},
#              'equ': {'equator', 'equivalent', 'frequent'},
#              'que': {'frequent'},
#              'uen': {'frequent'},
#              'ent': {'century',
#               'concentrate',
#               'content',
#               'deficient',
#               'different',
#               'entirely',
#               'equivalent',
#               'eventually',
#               'frequent',
#               'invented',
#               'parents',
#               'placement',
#               'president',
#               'scientific',
#               'scientists'},
#              'nt$': {'amount',
#               'antioxidant',
#               'content',
#               'deficient',
#               'different',
#               'elephant',
#               'equivalent',
#               'frequent',
#               'placement',
#               'pregnant',
#               'president',
#               'want'},
#              'buy': {'buy', 'buyer', 'buyers'},
#              'uye': {'buyer', 'buyers'},
#              'ers': {'bartenders',
#               'buyers',
#               'dieters',
#               'flowers',
#               'founders',
#               'gamblers',
#               'hamsters',
#               'makers',
#               'others',
#               'otters',
#               'passengers',
#               'person',
#               'prisoners',
#               'spiders',
#               'telemarketers',
#               'tellers',
#               'understanding',
#               'universe',
#               'users'},
#              'rs$': {'bartenders',
#               'buyers',
#               'cars',
#               'dieters',
#               'ears',
#               'flowers',
#               'founders',
#               'gamblers',
#               'hamsters',
#               'makers',
#               'others',
#               'otters',
#               'passengers',
#               'prisoners',
#               'receptors',
#               'spiders',
#               'stars',
#               'telemarketers',
#               'tellers',
#               'users',
#               'warriors',
#               'years'},
#              'hei': {'height', 'their'},
#              'eir': {'their'},
#              'ir$': {'air', 'repair', 'their'},
#              'foo': {'food', 'foot', 'footprints'},
#              'ood': {'blood', 'bloodhound', 'food', 'good'},
#              'od$': {'blood', 'food', 'god', 'good'},
#              '$he': {'he',
#               'head',
#               'heads',
#               'hear',
#               'heavy',
#               'height',
#               'held',
#               'help',
#               'her'},
#              'hea': {'head', 'heads', 'hear', 'heavy'},
#              'eav': {'heavy', 'leave'},
#              'avy': {'heavy'},
#              'vy$': {'heavy'},
#              '$us': {'use', 'used', 'users', 'using'},
#              'use': {'because',
#               'causes',
#               'house',
#               'mouse',
#               'use',
#               'used',
#               'users'},
#              'ser': {'users'},
#              '$3$': {'3'},
#              '$av': {'average', 'avocados'},
#              'ave': {'average',
#               'have',
#               'leave',
#               'slaves',
#               'travel',
#               'traveled',
#               'travels'},
#              'era': {'average',
#               'iterations',
#               'literally',
#               'opera',
#               'several',
#               'tolerance'},
#              'rag': {'average'},
#              'age': {'average', 'damage', 'language', 'message', 'stage'},
#              'ge$': {'average', 'damage', 'language', 'message', 'stage'},
#              '$pe': {'penny', 'people', 'per', 'person'},
#              'per': {'opera', 'per', 'person'},
#              'rso': {'person'},
#              'son': {'person',
#               'poison',
#               'poisonous',
#               'prisoners',
#               'reason',
#               'son'},
#              'on$': {'amazon',
#               'bacon',
#               'balloon',
#               'billion',
#               'don',
#               'execution',
#               'gallon',
#               'lion',
#               'london',
#               'million',
#               'on',
#               'onion',
#               'person',
#               'poison',
#               'population',
#               'reason',
#               'son',
#               'television'},
#              '$sp': {'space',
#               'spanish',
#               'speaking',
#               'spends',
#               'spiders',
#               'spin',
#               'spoils'},
#              'spe': {'speaking', 'spends'},
#              'pen': {'open', 'penny', 'ripen', 'spends'},
#              'end': {'bartenders', 'sends', 'spends', 'tend'},
#              'nds': {'diamonds', 'hands', 'pounds', 'sends', 'spends'},
#              '$6$': {'6'},
#              '$mo': {'mole',
#               'money',
#               'month',
#               'months',
#               'more',
#               'morning',
#               'most',
#               'mountain',
#               'mouse',
#               'mouth',
#               'moving'},
#              'mon': {'demonstrated', 'diamonds', 'money', 'month', 'months'},
#              'ont': {'contained',
#               'content',
#               'continuously',
#               'control',
#               'month',
#               'months'},
#              'nth': {'month', 'months'},
#              'ths': {'months'},
#              'hs$': {'months', 'weighs'},
#              'lif': {'california', 'life', 'lifeforms', 'lifetime', 'lift'},
#              'ife': {'life', 'lifeforms', 'lifetime'},
#              'fet': {'lifetime'},
#              'eti': {'lifetime', 'sometimes'},
#              'tim': {'intimidating',
#               'lifetime',
#               'sometimes',
#               'tim',
#               'time',
#               'times'},
#              'ime': {'lifetime', 'sometimes', 'time', 'times'},
#              'me$': {'become',
#               'game',
#               'lifetime',
#               'name',
#               'same',
#               'some',
#               'time'},
#              'wai': {'hawaii', 'waiting'},
#              'ait': {'waiting'},
#              'iti': {'definitions', 'waiting'},
#              'tin': {'continuously',
#               'erupting',
#               'intimidating',
#               'urinating',
#               'waiting'},
#              '$on': {'on', 'once', 'one', 'onion', 'only'},
#              '$re': {'re',
#               'reason',
#               'received',
#               'receptors',
#               'record',
#               'recorded',
#               'records',
#               'red',
#               'reduced',
#               'repair',
#               'republic',
#               'restrictive'},
#              'red': {'considered', 'red', 'reduced', 'watered'},
#              'ed$': {'added',
#               'assorted',
#               'banned',
#               'believed',
#               'bleed',
#               'boiled',
#               'called',
#               'changed',
#               'closed',
#               'considered',
#               'contained',
#               'crooked',
#               'demonstrated',
#               'derived',
#               'described',
#               'died',
#               'disguised',
#               'doubled',
#               'executed',
#               'expected',
#               'eyed',
#               'folded',
#               'fried',
#               'handed',
#               'hardboiled',
#               'haunted',
#               'highlighted',
#               'improved',
#               'invented',
#               'killed',
#               'lasted',
#               'launched',
#               'located',
#               'named',
#               'picked',
#               'punished',
#               'rained',
#               'received',
#               'recorded',
#               'red',
#               'reduced',
#               'stained',
#               'started',
#               'tracked',
#               'traveled',
#               'treated',
#               'tried',
#               'turned',
#               'united',
#               'used',
#               'watered'},
#              'lig': {'highlighted', 'light', 'lighter', 'lightning'},
#              'igh': {'eyesight',
#               'height',
#               'higher',
#               'highest',
#               'highlighted',
#               'light',
#               'lighter',
#               'lightning',
#               'night',
#               'right',
#               'thigh',
#               'weighs',
#               'weight'},
#              'ght': {'bought',
#               'eyesight',
#               'height',
#               'highlighted',
#               'light',
#               'lighter',
#               'lightning',
#               'night',
#               'right',
#               'thought',
#               'weight'},
#              'ht$': {'bought',
#               'eyesight',
#               'height',
#               'light',
#               'night',
#               'right',
#               'thought',
#               'weight'},
#              '$tu': {'tunnel', 'turn', 'turned'},
#              'tur': {'century',
#               'furniture',
#               'gestures',
#               'rupture',
#               'saturn',
#               'turn',
#               'turned'},
#              'urn': {'burn', 'burns', 'furniture', 'saturn', 'turn', 'turned'},
#              'rn$': {'born', 'burn', 'saturn', 'southern', 'turn'},
#              '$gr': {'grains', 'greater', 'greek', 'green', 'growing'},
#              'gre': {'greater', 'greek', 'green'},
#              'ree': {'free', 'greek', 'green', 'streets', 'three'},
#              'een': {'green', 'seen'},
#              'en$': {'broken',
#               'even',
#               'garden',
#               'given',
#               'golden',
#               'green',
#               'men',
#               'often',
#               'open',
#               'ripen',
#               'seen',
#               'stolen',
#               'ten',
#               'when',
#               'women'},
#              '$4$': {'4'},
#              'lar': {'dollar', 'larger', 'largest', 'solar'},
#              'arg': {'larger', 'largest'},
#              'rge': {'larger', 'largest'},
#              'ges': {'gestures', 'largest', 'strongest'},
#              'est': {'gestures',
#               'highest',
#               'largest',
#               'oldest',
#               'restrictive',
#               'strongest',
#               'wrestler'},
#              'st$': {'against',
#               'dust',
#               'first',
#               'highest',
#               'just',
#               'largest',
#               'last',
#               'lost',
#               'most',
#               'oldest',
#               'past',
#               'strongest'},
#              'rec': {'received',
#               'receptors',
#               'record',
#               'recorded',
#               'records',
#               'wreck'},
#              'eco': {'become', 'record', 'recorded', 'records', 'second'},
#              'ord': {'according',
#               'border',
#               'order',
#               'record',
#               'recorded',
#               'records',
#               'word',
#               'words'},
#              'rde': {'border',
#               'garden',
#               'harder',
#               'murder',
#               'order',
#               'recorded'},
#              'ded': {'added', 'folded', 'handed', 'recorded'},
#              '$sn': {'snake', 'sneeze', 'snore', 'snow', 'snowflake'},
#              'sno': {'snore', 'snow', 'snowflake'},
#              'now': {'known', 'now', 'snow', 'snowflake'},
#              'owf': {'snowflake'},
#              'wfl': {'snowflake'},
#              'fla': {'flaps', 'flat', 'snowflake'},
#              'lak': {'snowflake'},
#              'ake': {'make',
#               'makers',
#               'makes',
#               'snake',
#               'snowflake',
#               'take',
#               'takes'},
#              'ke$': {'like', 'make', 'poke', 'snake', 'snowflake', 'take'},
#              'was': {'was', 'wasn', 'wasps'},
#              'as$': {'as', 'gorillas', 'has', 'las', 'vegas', 'was'},
#              '$ke': {'keep', 'keogh', 'ketchup'},
#              'keo': {'keogh'},
#              'eog': {'keogh'},
#              'ogh': {'keogh'},
#              'gh$': {'enough', 'keogh', 'thigh'},
#              '$mt': {'mt'},
#              'mt$': {'mt'},
#              '$du': {'duck', 'during', 'dust'},
#              'dur': {'during'},
#              'uri': {'during', 'urinate', 'urinating'},
#              'rin': {'coloring',
#               'during',
#               'earrings',
#               'fingerprints',
#               'footprints',
#               'prints',
#               'ring',
#               'urinate',
#               'urinating'},
#              '$ye': {'year', 'years'},
#              'yea': {'year', 'years'},
#              'ear': {'ear',
#               'earrings',
#               'ears',
#               'earth',
#               'fear',
#               'hear',
#               'tear',
#               'wear',
#               'year',
#               'years'},
#              'ar$': {'dollar',
#               'ear',
#               'fear',
#               'hear',
#               'roar',
#               'solar',
#               'tear',
#               'war',
#               'wear',
#               'year'},
#              '$18': {'18', '184', '1887'},
#              '188': {'1887'},
#              '887': {'1887'},
#              '87$': {'1887', '87', '987'},
#              '$an': {'an',
#               'and',
#               'animal',
#               'animals',
#               'another',
#               'antioxidant',
#               'ants',
#               'any'},
#              '$15': {'15', '150', '151', '152', '153', '154', '155', '15th'},
#              '15$': {'115', '15'},
#              'inc': {'inch', 'inches'},
#              'nch': {'crunch', 'french', 'inch', 'inches', 'launched'},
#              'che': {'cherophobia',
#               'chess',
#               'chewing',
#               'cockroaches',
#               'inches',
#               'launched',
#               'pouches'},
#              'hes': {'chess',
#               'cockroaches',
#               'highest',
#               'inches',
#               'pouches',
#               'these'},
#              '$wi': {'wide', 'will', 'willing', 'winning', 'with', 'without'},
#              'wid': {'wide'},
#              'ide': {'considered',
#               'evidence',
#               'inside',
#               'outside',
#               'president',
#               'spiders',
#               'wide'},
#              'de$': {'code', 'inside', 'made', 'outside', 'wide'},
#              '$5$': {'5'},
#              'bur': {'burn', 'burns', 'burp'},
#              'mor': {'more', 'morning'},
#              'alo': {'calories'},
#              'lor': {'calories', 'coloring'},
#              'ori': {'calories',
#               'coloring',
#               'gorilla',
#               'gorillas',
#               'orifice',
#               'originally'},
#              'rie': {'berries',
#               'blueberries',
#               'calories',
#               'fried',
#               'libraries',
#               'tried'},
#              'ies': {'berries',
#               'blueberries',
#               'butterflies',
#               'calories',
#               'libraries'},
#              '$sl': {'slaves', 'sleep', 'sleeping', 'slinky', 'sloth'},
#              'sle': {'asleep', 'sleep', 'sleeping'},
#              'lee': {'asleep', 'bleed', 'bleeding', 'sleep', 'sleeping'},
#              'eep': {'asleep', 'keep', 'sheep', 'sleep', 'sleeping'},
#              'epi': {'sleeping'},
#              'pin': {'jumping', 'pine', 'sleeping', 'spin'},
#              'tha': {'than', 'that'},
#              'han': {'buchanan',
#               'chance',
#               'chandelier',
#               'changed',
#               'elephant',
#               'elephants',
#               'handed',
#               'hands',
#               'hang',
#               'hanging',
#               'than'},
#              'an$': {'an',
#               'buchanan',
#               'can',
#               'canadian',
#               'human',
#               'japan',
#               'man',
#               'organ',
#               'plan',
#               'than',
#               'woman'},
#              '$do': {'do',
#               'doesn',
#               'dogs',
#               'dollar',
#               'dolphins',
#               'don',
#               'donald',
#               'donkey',
#               'doubled',
#               'down'},
#              'do$': {'do'},
#              'wat': {'watching', 'water', 'watered', 'waterfall'},
#              'atc': {'match', 'watching'},
#              'tch': {'ketchup', 'match', 'stretch', 'watching'},
#              'chi': {'child', 'watching'},
#              'hin': {'clothing', 'dolphins', 'things', 'watching'},
#              '$te': {'tear',
#               'teeth',
#               'telemarketers',
#               'telephone',
#               'telescopes',
#               'television',
#               'tellers',
#               'telling',
#               'temples',
#               'ten',
#               'tend',
#               'text'},
#              'tel': {'approximately',
#               'telemarketers',
#               'telephone',
#               'telescopes',
#               'television',
#               'tellers',
#               'telling'},
#              'ele': {'celery',
#               'elephant',
#               'elephants',
#               'forelegs',
#               'homeless',
#               'telemarketers',
#               'telephone',
#               'telescopes',
#               'television',
#               'traveled'},
#              'lev': {'television'},
#              'evi': {'evidence', 'television'},
#              'vis': {'invisible', 'television', 'visit'},
#              'isi': {'invisible', 'television', 'visit'},
#              'sio': {'television'},
#              'ion': {'billion',
#               'calculations',
#               'definitions',
#               'execution',
#               'iterations',
#               'lion',
#               'lions',
#               'million',
#               'millionaire',
#               'onion',
#               'population',
#               'television'},
#              'her': {'another',
#               'cherophobia',
#               'farther',
#               'father',
#               'her',
#               'higher',
#               'leather',
#               'other',
#               'others',
#               'southern',
#               'there',
#               'where'},
#              'ere': {'considered',
#               'different',
#               'there',
#               'watered',
#               'were',
#               'where'},
#              '$ar': {'are', 'area', 'army', 'around'},
#              'are': {'are', 'area', 'cigarette', 'parents'},
#              'fef': {'lifeforms'},
#              'efo': {'before', 'lifeforms'},
#              'for': {'before', 'california', 'for', 'forelegs', 'lifeforms'},
#              'orm': {'lifeforms', 'worms'},
#              'rms': {'lifeforms', 'worms'},
#              'ms$': {'atoms', 'lifeforms', 'worms'},
#              'liv': {'live', 'living', 'saliva'},
#              'ivi': {'diving', 'living'},
#              'vin': {'diving', 'living', 'moving'},
#              '$sk': {'skin', 'sky'},
#              'ski': {'skin'},
#              'kin': {'kind', 'kindle', 'making', 'skin', 'speaking'},
#              'peo': {'people'},
#              'eop': {'people'},
#              'opl': {'people'},
#              'ple': {'apple',
#               'apples',
#               'depletes',
#               'people',
#               'simple',
#               'temples'},
#              '$7$': {'7'},
#              'sou': {'southern'},
#              'out': {'about',
#               'mouth',
#               'out',
#               'outlines',
#               'outside',
#               'southern',
#               'without'},
#              'uth': {'mouth', 'southern'},
#              'ern': {'internal', 'southern', 'underneath'},
#              '$se': {'sea',
#               'second',
#               'see',
#               'seen',
#               'sell',
#               'sends',
#               'set',
#               'several'},
#              'sea': {'sea'},
#              'ea$': {'area', 'flea', 'sea'},
#              '$ot': {'other', 'others', 'otters'},
#              'ott': {'lottery', 'otters'},
#              'tte': {'butterflies',
#               'cigarette',
#               'lottery',
#               'matter',
#               'otters'},
#              'ter': {'after',
#               'bacteria',
#               'butterflies',
#               'dieters',
#               'greater',
#               'hamsters',
#               'internal',
#               'iterations',
#               'jupiter',
#               'later',
#               'lighter',
#               'literally',
#               'lottery',
#               'matter',
#               'otters',
#               'rooster',
#               'shorter',
#               'telemarketers',
#               'water',
#               'watered',
#               'waterfall'},
#              '$ha': {'hairy',
#               'half',
#               'hammurabi',
#               'hamsters',
#               'handed',
#               'hands',
#               'hang',
#               'hanging',
#               'happy',
#               'hardboiled',
#               'harder',
#               'has',
#               'hat',
#               'haunted',
#               'have',
#               'hawaii'},
#              'hav': {'have'},
#              've$': {'attractive',
#               'believe',
#               'five',
#               'have',
#               'leave',
#               'live',
#               'negative',
#               'restrictive',
#               'steve'},
#              '$fl': {'flaps',
#               'flat',
#               'flea',
#               'float',
#               'floorboards',
#               'flowers',
#               'flying'},
#              'lap': {'flaps'},
#              'aps': {'flaps'},
#              'ps$': {'camps', 'drops', 'flaps', 'wasps'},
#              '$un': {'unable',
#               'under',
#               'underneath',
#               'understanding',
#               'united',
#               'universe',
#               'until'},
#              'nde': {'bartenders',
#               'chandelier',
#               'founders',
#               'handed',
#               'under',
#               'underneath',
#               'understanding',
#               'wonder'},
#              'der': {'bartenders',
#               'border',
#               'considered',
#               'derived',
#               'founders',
#               'harder',
#               'murder',
#               'older',
#               'order',
#               'spiders',
#               'under',
#               'underneath',
#               'understanding',
#               'wonder'},
#              'rel': {'entirely', 'forelegs'},
#              'leg': {'forelegs', 'illegal', 'legal', 'legs'},
#              'egs': {'forelegs', 'legs'},
#              'gs$': {'ceilings',
#               'dogs',
#               'earrings',
#               'forelegs',
#               'legs',
#               'pigs',
#               'things'},
#              'hat': {'hat', 'that', 'what'},
#              'at$': {'at',
#               'eat',
#               'flat',
#               'float',
#               'hat',
#               'meat',
#               'that',
#               'what'},
#              '$ac': {'according', 'act', 'actually'},
#              '$as': {'as', 'asleep', 'assorted'},
#              '$po': {'pockets',
#               'poison',
#               'poisonous',
#               'poke',
#               'pools',
#               'population',
#               'possible',
#               'potassium',
#               'pouches',
#               'pound',
#               'pounds',
#               'powerful'},
#              'poc': {'pockets'},
#              'ock': {'clock', 'clocks', 'cockroaches', 'pockets', 'rocks'},
#              'cke': {'picked', 'pockets', 'tickets', 'tracked'},
#              'ket': {'ketchup', 'pockets', 'telemarketers', 'tickets'},
#              'ets': {'planets', 'pockets', 'streets', 'tickets'},
#              'ts$': {'adults',
#               'ants',
#               'bolts',
#               'cats',
#               'coconuts',
#               'drifts',
#               'elephants',
#               'fingerprints',
#               'footprints',
#               'insects',
#               'its',
#               'nuts',
#               'pants',
#               'parents',
#               'planets',
#               'pockets',
#               'prints',
#               'products',
#               'scientists',
#               'streets',
#               'tickets'},
#              '$wh': {'whale',
#               'what',
#               'wheel',
#               'when',
#               'where',
#               'while',
#               'whistle',
#               'who',
#               'whose'},
#              'whe': {'wheel', 'when', 'where'},
#              'hen': {'when'},
#              '$di': {'diamonds',
#               'didn',
#               'die',
#               'died',
#               'diet',
#               'dieters',
#               'different',
#               'dig',
#               'disguised',
#               'diving'},
#              'div': {'diving'},
#              'hey': {'they'},
#              'ey$': {'donkey', 'honey', 'marley', 'money', 'they'},
#              'se$': {'because',
#               'close',
#               'house',
#               'mouse',
#               'nose',
#               'phrase',
#               'rise',
#               'these',
#               'those',
#               'universe',
#               'use',
#               'whose'},
#              'ese': {'these'},
#              'pou': {'pouches', 'pound', 'pounds'},
#              'ouc': {'pouches'},
#              'uch': {'buchanan', 'much', 'pouches', 'such'},
#              '$st': {'stage',
#               'stained',
#               'stars',
#               'started',
#               'state',
#               'states',
#               'stem',
#               'steve',
#               'still',
#               'stolen',
#               'stop',
#               'store',
#               'streets',
#               'stretch',
#               'stronger',
#               'strongest',
#               'struck',
#               'study'},
#              'sto': {'stolen', 'stop', 'store'},
#              'tor': {'equator', 'receptors', 'store'},
#              '$ro': {'roar', 'rocks', 'rooster'},
#              'roc': {'crocodile', 'rocks'},
#              'cks': {'clocks', 'rocks'},
#              'ks$': {'books', 'clocks', 'rocks', 'sharks', 'walks', 'weeks'},
#              '$8$': {'8'},
#              '$13': {'13',
#               '130',
#               '131',
#               '132',
#               '133',
#               '134',
#               '135',
#               '136',
#               '137',
#               '138',
#               '1386',
#               '139',
#               '13th'},
#              '138': {'138', '1386'},
#              '386': {'1386'},
#              '86$': {'1386', '1986', '86'},
#              '$pi': {'picked',
#               'piece',
#               'pig',
#               'pigs',
#               'pills',
#               'pine',
#               'pirates'},
#              'pig': {'pig', 'pigs'},
#              'ig$': {'big', 'dig', 'pig'},
#              'fra': {'france'},
#              'ran': {'france', 'tarantula', 'tolerance', 'translates'},
#              'anc': {'chance', 'france', 'tolerance'},
#              'nce': {'audience',
#               'bounce',
#               'chance',
#               'concentrate',
#               'evidence',
#               'france',
#               'once',
#               'pronounce',
#               'tolerance'},
#              'ce$': {'audience',
#               'bounce',
#               'chance',
#               'evidence',
#               'face',
#               'france',
#               'once',
#               'orifice',
# ...
#              'lla': {'dollar', 'gorilla', 'gorillas'},
#              '$bi': {'bible',
#               'big',
#               'bigger',
#               'bill',
#               'billion',
#               'biography',
#               'birds',
#               'birth'},
#              'bil': {'ability', 'bill', 'billion'},
#              'fol': {'folded', 'follow'},
#              'lac': {'place', 'placement'},
#              'ace': {'face', 'place', 'placement', 'space', 'surface'},
#              'bef': {'before'},
#              'tea': {'instead', 'tear'},
#              '$24': {'24'},
#              '24$': {'124', '24'},
#              'sne': {'sneeze'},
#              'eez': {'sneeze'},
#              'eze': {'sneeze'},
#              'ze$': {'size', 'sneeze'},
#              'rav': {'travel', 'traveled', 'travels'},
#              'els': {'travels', 'vessels'},
#              '100': {'100', '100th'},
#              'les': {'apples',
#               'beetles',
#               'enables',
#               'homeless',
#               'less',
#               'miles',
#               'muscles',
#               'particles',
#               'telescopes',
#               'temples'},
#              '$ho': {'hold',
#               'holding',
#               'holds',
#               'homeless',
#               'honey',
#               'hot',
#               'hour',
#               'house',
#               'however'},
#              'hou': {'bloodhound', 'hour', 'house', 'thought', 'without'},
#              'has': {'has'},
#              'led': {'boiled',
#               'called',
#               'doubled',
#               'hardboiled',
#               'killed',
#               'traveled'},
#              '$pa': {'pain',
#               'pants',
#               'parents',
#               'particles',
#               'passengers',
#               'past'},
#              'pas': {'passengers', 'past', 'toothpaste'},
#              'ast': {'castle',
#               'last',
#               'lasted',
#               'past',
#               'taste',
#               'toothpaste'},
#              'min': {'hummingbird', 'minutes', 'swimming', 'vitamin'},
#              'nut': {'coconut', 'coconuts', 'minutes', 'nuts'},
#              'tes': {'depletes',
#               'minutes',
#               'pirates',
#               'prostitutes',
#               'states',
#               'translates'},
#              '$ta': {'take', 'takes', 'tall', 'tarantula', 'taste'},
#              'tak': {'take', 'takes'},
#              'slo': {'sloth'},
#              'lot': {'clothing', 'lot', 'lottery', 'sloth'},
#              'oth': {'another',
#               'both',
#               'clothing',
#               'other',
#               'others',
#               'sloth',
#               'toothpaste'},
#              'el$': {'feel', 'travel', 'tunnel', 'vessel', 'wheel'},
#              'pop': {'population'},
#              'opu': {'population'},
#              'pul': {'population'},
#              'ula': {'calculations', 'population', 'tarantula'},
#              'lat': {'calculations',
#               'flat',
#               'later',
#               'population',
#               'translates'},
#              '$le': {'leather', 'leave', 'left', 'legal', 'legs', 'less'},
#              'lef': {'left'},
#              'eft': {'left'},
#              'ft$': {'drift', 'left', 'lift', 'soft'},
#              '$br': {'brain',
#               'brains',
#               'breath',
#               'breathe',
#               'britain',
#               'broken'},
#              'bro': {'broken'},
#              'rok': {'broken'},
#              'oke': {'broken', 'crooked', 'poke'},
#              'ken': {'broken'},
#              'loc': {'clock', 'clocks', 'located'},
#              '$ri': {'right', 'ring', 'ripen', 'rise'},
#              'rig': {'originally', 'right'},
#              '$tw': {'twice', 'two'},
#              'two': {'two'},
#              'wo$': {'two'},
#              '$da': {'daily', 'damage', 'dark', 'dart', 'day', 'days'},
#              'day': {'day', 'days', 'friday', 'sunday'},
#              '$25': {'25', '250', '2500'},
#              '25$': {'125', '25'},
#              'acc': {'according'},
#              'cco': {'according'},
#              'rdi': {'according'},
#              '$am': {'amazon', 'americans', 'amount'},
#              'ama': {'amazon', 'damage'},
#              'maz': {'amazon'},
#              'azo': {'amazon'},
#              'zon': {'amazon'},
#              'mos': {'most'},
#              'ost': {'lost', 'most', 'ostrich', 'prostitutes', 'rooster'},
#              'hig': {'higher', 'highest', 'highlighted', 'thigh'},
#              'ghl': {'highlighted'},
#              'hli': {'highlighted'},
#              'hte': {'highlighted', 'lighter'},
#              'boo': {'book', 'books', 'boomslang'},
#              'ook': {'book', 'books', 'crooked', 'look'},
#              'oks': {'books'},
#              '$ki': {'kill', 'killed', 'kind', 'kindle', 'kiss'},
#              'ind': {'find', 'kind', 'kindle'},
#              'ndl': {'kindle'},
#              'dle': {'kindle'},
#              'bib': {'bible'},
#              'ste': {'hamsters',
#               'instead',
#               'lasted',
#               'rooster',
#               'stem',
#               'steve',
#               'system',
#               'taste',
#               'toothpaste'},
#              'tev': {'steve'},
#              '$jo': {'jobs'},
#              'job': {'jobs'},
#              'obs': {'jobs'},
#              'bs$': {'jobs'},
#              'bio': {'biography'},
#              'iog': {'biography'},
#              'ogr': {'biography'},
#              'gra': {'biography', 'grains'},
#              'rap': {'biography'},
#              'aph': {'biography'},
#              'phy': {'biography', 'physically'},
#              'hy$': {'biography'},
#              'hun': {'hunger'},
#              'ung': {'hunger'},
#              'nge': {'changed',
#               'fingerprints',
#               'hunger',
#               'passengers',
#               'stronger',
#               'strongest'},
#              'ger': {'bigger',
#               'fingerprints',
#               'hunger',
#               'larger',
#               'passengers',
#               'stronger'},
#              '$26': {'26'},
#              '26$': {'126', '26'},
#              'bob': {'bob'},
#              'ob$': {'bob'},
#              '$ma': {'made',
#               'make',
#               'makers',
#               'makes',
#               'making',
#               'male',
#               'mammal',
#               'man',
#               'many',
#               'mark',
#               'marley',
#               'marry',
#               'match',
#               'mathematical',
#               'matter',
#               'may'},
#              'mar': {'mark', 'marley', 'marry', 'telemarketers'},
#              'arl': {'marley'},
#              'rle': {'marley'},
#              'ley': {'marley'},
#              'las': {'glass', 'gorillas', 'las', 'last', 'lasted', 'plasma'},
#              'rds': {'birds', 'floorboards', 'records', 'words'},
#              'die': {'audience', 'die', 'died', 'diet', 'dieters'},
#              'ied': {'died', 'fried', 'tried'},
#              'wer': {'flowers', 'powerful', 'were'},
#              'uy$': {'buy'},
#              'fe$': {'giraffe', 'life'},
#              '$27': {'27'},
#              '27$': {'127', '27', '527'},
#              'mol': {'mole'},
#              'ole': {'mole', 'stolen', 'tolerance'},
#              'dig': {'dig'},
#              'tun': {'tunnel'},
#              'unn': {'tunnel'},
#              'nne': {'banned', 'guinness', 'tunnel'},
#              'nel': {'tunnel'},
#              '$30': {'30', '300'},
#              '300': {'300'},
#              '$fe': {'fear', 'fecal', 'feel', 'feet'},
#              'fee': {'feel', 'feet'},
#              'eet': {'beetles', 'feet', 'streets', 'teeth'},
#              'ong': {'long', 'stronger', 'strongest', 'tongue', 'wrong'},
#              'onl': {'only'},
#              'nly': {'only'},
#              '$ni': {'night'},
#              'nig': {'night'},
#              '$28': {'28'},
#              '28$': {'128', '28'},
#              'hip': {'hippo'},
#              'ipp': {'hippo'},
#              'ppo': {'hippo'},
#              'po$': {'hippo'},
#              '$op': {'open', 'opera'},
#              'ope': {'open', 'opera', 'telescopes'},
#              'big': {'big', 'bigger'},
#              '$en': {'enables',
#               'energy',
#               'england',
#               'english',
#               'enough',
#               'entirely'},
#              'eno': {'enough', 'venom'},
#              'nou': {'enough', 'poisonous', 'pronounce'},
#              'fit': {'fit'},
#              'tal': {'tall', 'total'},
#              '$29': {'29'},
#              '29$': {'129', '29'},
#              '$cu': {'cut', 'cute'},
#              'oni': {'onion'},
#              'nio': {'onion'},
#              'hel': {'held', 'help'},
#              'elp': {'help'},
#              'lp$': {'help'},
#              'kee': {'keep'},
#              'ep$': {'asleep', 'keep', 'sheep', 'sleep'},
#              '$cr': {'crocodile', 'crooked', 'crunch', 'cry', 'crying'},
#              'cry': {'cry', 'crying'},
#              'ryi': {'crying', 'drying', 'trying'},
#              'yin': {'crying', 'drying', 'dying', 'flying', 'trying'},
#              '30$': {'130', '1930', '30'},
#              'tre': {'streets', 'stretch', 'treated'},
#              'ret': {'cigarette', 'concrete', 'stretch'},
#              'etc': {'etc', 'ketchup', 'stretch'},
#              'sli': {'slinky'},
#              'ink': {'slinky'},
#              'nky': {'slinky'},
#              'ky$': {'sky', 'slinky'},
#              'unt': {'amount',
#               'country',
#               'fountain',
#               'haunted',
#               'mountain',
#               'until'},
#              'il$': {'until'},
#              'mea': {'meaning', 'means', 'measure', 'meat'},
#              'eas': {'measure', 'reason'},
#              'asu': {'measure'},
#              'sur': {'measure', 'surface'},
#              'ure': {'failures',
#               'furniture',
#               'gestures',
#               'measure',
#               'rupture'},
#              '$87': {'87'},
#              '$31': {'31'},
#              '31$': {'131', '31'},
#              'al$': {'al',
#               'animal',
#               'deal',
#               'fecal',
#               'illegal',
#               'internal',
#               'legal',
#               'mammal',
#               'mathematical',
#               'several',
#               'total'},
#              'cap': {'cap', 'capable', 'capone'},
#              'apo': {'capone'},
#              'pon': {'capone'},
#              'bus': {'business'},
#              'usi': {'business', 'using'},
#              'ine': {'business',
#               'contained',
#               'line',
#               'medicine',
#               'outlines',
#               'pine',
#               'rained',
#               'stained'},
#              'nes': {'bones', 'business', 'guinness', 'outlines'},
#              'car': {'card', 'carrot', 'cars'},
#              'ard': {'card', 'floorboards', 'garden', 'hardboiled', 'harder'},
#              'rd$': {'card', 'hummingbird', 'record', 'word'},
#              'sai': {'said'},
#              'aid': {'said'},
#              'id$': {'said'},
#              '$fu': {'fun', 'furniture'},
#              'fur': {'furniture'},
#              'rni': {'california', 'furniture', 'morning'},
#              'nit': {'definitions', 'furniture', 'united'},
#              'itu': {'furniture', 'prostitutes'},
#              '$de': {'dead',
#               'deal',
#               'dealer',
#               'deficient',
#               'definitions',
#               'demonstrated',
#               'density',
#               'depletes',
#               'derived',
#               'described'},
#              'dea': {'dead', 'deal', 'dealer'},
#              'eal': {'deal', 'dealer', 'zealand'},
#              'ler': {'allergic',
#               'celery',
#               'dealer',
#               'gamblers',
#               'tellers',
#               'tolerance',
#               'wrestler'},
#              '$32': {'32', '321'},
#              '32$': {'132', '32'},
#              'lle': {'allergic',
#               'called',
#               'collect',
#               'illegal',
#               'killed',
#               'tellers'},
#              'lec': {'collect'},
#              'fat': {'father'},
#              'any': {'any', 'many'},
#              'ny$': {'any', 'many', 'penny'},
#              '$33': {'33'},
#              '33$': {'133', '33'},
#              '$ba': {'baby',
#               'back',
#               'bacon',
#               'bacteria',
#               'ball',
#               'balloon',
#               'banging',
#               'banned',
#               'bartenders'},
#              'ban': {'banging', 'banned'},
#              'ead': {'dead', 'head', 'heads', 'instead'},
#              'ad$': {'dead', 'head', 'instead'},
#              '$ag': {'against'},
#              'aga': {'against'},
#              'gai': {'against'},
#              'ain': {'against',
#               'brain',
#               'brains',
#               'britain',
#               'contained',
#               'fountain',
#               'grains',
#               'mountain',
#               'pain',
#               'rained',
#               'raining',
#               'rains',
#               'stained',
#               'train'},
#              'nst': {'against', 'demonstrated', 'instead'},
#              'rns': {'burns', 'newborns'},
#              '150': {'150'},
#              '50$': {'150', '250', '50'},
#              '$34': {'34', '345'},
#              '34$': {'134', '34'},
#              '$95': {'95'},
#              '95$': {'95'},
#              'tex': {'text'},
#              'xt$': {'text'},
#              'thi': {'clothing', 'thigh', 'things', 'thirsty', 'this'},
#              'ngs': {'ceilings', 'earrings', 'things'},
#              'cou': {'could', 'country', 'court'},
#              'nev': {'never'},
#              'say': {'say'},
#              '$35': {'35'},
#              '35$': {'135', '35'},
#              'cro': {'crocodile', 'crooked'},
#              'oco': {'coconut', 'coconuts', 'crocodile'},
#              'cod': {'code', 'crocodile'},
#              'odi': {'crocodile'},
#              'dil': {'crocodile'},
#              'pok': {'poke'},
#              'its': {'its'},
#              'ton': {'tongue'},
#              'ngu': {'language', 'tongue'},
#              'gue': {'tongue'},
#              'ue$': {'blue', 'sue', 'tongue'},
#              '$36': {'36'},
#              '36$': {'136', '36'},
#              '$ph': {'phrase', 'physically'},
#              'hys': {'physically'},
#              'ysi': {'physically'},
#              'sic': {'physically'},
#              'ica': {'americans', 'mathematical', 'physically'},
#              'lly': {'actually',
#               'eventually',
#               'literally',
#               'originally',
#               'physically'},
#              '$im': {'impossible', 'improved'},
#              'imp': {'impossible', 'improved', 'simple'},
#              'mpo': {'impossible'},
#              'igs': {'pigs'},
#              'loo': {'balloon', 'blood', 'bloodhound', 'floorboards', 'look'},
#              'ok$': {'book', 'look'},
#              'int': {'fingerprints',
#               'footprints',
#               'internal',
#               'intimidating',
#               'into',
#               'prints'},
#              'nto': {'into'},
#              'sky': {'sky'},
#              '$37': {'37'},
#              '37$': {'137', '37'},
#              'uin': {'guinness'},
#              'inn': {'guinness', 'winning'},
#              'hol': {'alcohol', 'hold', 'holding', 'holds'},
#              'bei': {'being'},
#              'ein': {'being'},
#              'oft': {'often', 'soft'},
#              'fte': {'after', 'often'},
#              'ten': {'bartenders', 'content', 'often', 'ten', 'tend'},
#              'tol': {'stolen', 'tolerance'},
#              'lib': {'libraries'},
#              'ibr': {'libraries'},
#              'bra': {'brain', 'brains', 'libraries'},
#              'rar': {'libraries'},
#              'ari': {'libraries'},
#              '$38': {'38'},
#              '38$': {'138', '38'},
#              'dry': {'drying'},
#              'fru': {'fruit'},
#              'rui': {'fruit'},
#              'uit': {'fruit'},
#              'dep': {'depletes'},
#              ...})

# %%
generate_wildcard_options("*ints", kgram_idx, inverted_idx)
# Out:
# {'fingerprints', 'footprints', 'prints'}

# %%
results = search_wildcard("*ick*", kgram_idx, inverted_idx, facts)
results
# Out:
# ['41. Blueberries will not ripen until they are picked.',
#  "108. The giraffe's tongue is so long that they can lick the inside of their own ear.",
#  '67. The chance of you dying on the way to get lottery tickets is actually greater than your chance of winning.']

# %% [markdown]
# ### 1.1.3. Tests

# %%
index_orig_forms = build_inverted_index_orig_forms(facts)
k_gram_index = build_k_gram_index(index_orig_forms, 3)

wildcard = "re*ed"

wildcard_options = generate_wildcard_options(wildcard, k_gram_index, index_orig_forms)
print(wildcard_options)
assert (len(wildcard_options) >= 3)
assert ("red" not in wildcard_options)

wildcard_results = search_wildcard(wildcard, k_gram_index, index_orig_forms, facts)
# some pretty printing
for r in wildcard_results:
	# highlight terms for visual evaluation
	for term in wildcard_options:
		r = re.sub(r'(' + term + ')', r'\033[1m\033[91m\1\033[0m', r, flags=re.I)
	print(r)

assert (len(wildcard_results) >= 3)

assert "13. James Buchanan, the 15th U.S. president continuously bought slaves with his own money in order to free them." in search_wildcard(
	"pres*dent", k_gram_index, index_orig_forms, facts)
assert "40. 9 out of 10 Americans are deficient in Potassium." in search_wildcard("p*tas*um", k_gram_index,
	index_orig_forms, facts)
assert "61. A man from Britain changed his name to Tim Pppppppppprice to make it harder for telemarketers to pronounce." in search_wildcard(
	"*price", k_gram_index, index_orig_forms, facts)
# Out:
# {'received', 'reduced', 'recorded'}
# 134. A person can live without food for about a month, but only about a week without water. If the amount of water in your body is reduced by just 1%, you'll feel thirsty. If it's reduced by 10%, you'll die.
# 102. More than 50% of the people in the world have never made or received a telephone call.
# 4. The largest recorded snowflake was in Keogh, MT during year 1887, and was 15 inches wide.

# %% [markdown]
# ## 1.2. Handling typos
#
# ### 1.2.0. Dataset
#
# Download github typo dataset from [here](https://github.com/mhagiwara/github-typo-corpus).
# Load it with this code:

# %%
# !pip install jsonlines
# Out:
# Requirement already satisfied: jsonlines in /home/a/Documents/Innopolis/5 Sem - F24/Information Retrieval/.venv/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/lib/python3.11/site-packages (from jsonlines) (23.2.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import jsonlines

dataset_file = "github-typo-corpus.v1.0.0.jsonl"

dataset = []
other_langs = set()

with jsonlines.open(dataset_file) as reader:
	for obj in reader:
		for edit in obj['edits']:
			if edit['src']['lang'] != 'eng':
				other_langs.add(edit['src']['lang'])
				continue

			if edit['is_typo']:
				src, tgt = edit['src']['text'], edit['tgt']['text']
				if src.lower() != tgt.lower():
					dataset.append((edit['src']['text'], edit['tgt']['text']))

print(f"Dataset size = {len(dataset)}")
# Out:
# Dataset size = 245909

# %% [markdown]
# #### Explore sample typos
# Please, explore the dataset. You may see, that this is
# - mostly markdown
# - some common mistakes with do/does
# - some just refer to punctuation typos (which we do not consider)

# %%
for pair in dataset[1010:1020]:
	print(f"{pair[0]} => {pair[1]}")
# Out:
#         """Make am instance. =>         """Make an instance.
# * travis: test agains Node.js 11 => * travis: test against Node.js 11
# The parser receive a string and returns an array inside a user-provided  => The parser receives a string and returns an array inside a user-provided
# CSV data is send through the `write` function and the resulted data is obtained => CSV data is sent through the `write` function and the resulting data is obtained
# One useful function part of the Stream API is `pipe` to interact between  => One useful function of the Stream API is `pipe` to interact between
# source to a `stream.Writable` object destination. This example available as  => source to a `stream.Writable` object destination. This example is available as
# `node samples/pipe.js` read the file, parse its content and transform it. => `node samples/pipe.js` and reads the file, parses its content and transforms it.
# Most of the generator is imported from its parent project [CSV][csv] in a effort  => Most of the generator is imported from its parent project [CSV][csv] in an effort
# *   `quote`             Optionnal character surrounding a field, one character only, defaults to double quotes.    => *   `quote`             Optional character surrounding a field, one character only, defaults to double quotes.
# The parser receive a string and return an array inside a user-provided  => The parser receive a string and returns an array inside a user-provided

# %% [markdown]
# #### 1.2.0.1. Build a dataset vocabulary
# Here we prepare a vocabulary for spellchecker testing and for estimating overall correction quality. Consider only word-level. Be carefull, there is markdown (e.g. \`name\`. \[url\]\(http://url)) and comment symbols (\#, //, \*).

# %%
def sent_to_words(sent):
	# splits sentence to words, filtering out non-alphabetical terms
	words = nltk.word_tokenize(sent)
	words_filtered = filter(lambda x: x.isalpha(), words)
	return words_filtered

# %%
from collections import Counter

vocabulary = Counter()
for pair in dataset:
	for word in sent_to_words(pair[1].lower()):
		vocabulary[word] += 1
len(vocabulary)
# Out:
# 63724

# %%
from itertools import islice

print(list(islice(vocabulary.items(), 10)))
# Out:
# [('function', 6193), ('de', 82), ('deutsch', 4), ('nocomments', 2), ('you', 42075), ('can', 26027), ('disable', 532), ('comments', 360), ('for', 44756), ('the', 207017)]

# %% [markdown]
# ### 1.2.1. Implement context-independent spellcheker (Trigrams with Jaccard coefficient) ##

# %%
k_gram_index_github = build_k_gram_index(vocabulary, 3)

# %%
def iou(kgrams, word):
	k = len(next(iter(kgrams)))
	wgrams = set(k_grams(word, k))
	
	i = len(kgrams & wgrams)
	u = len(kgrams | wgrams)
	
	return i / u
	
	
def fix_typo_kgram(word, k_gram_index) -> list:
	#TODO return best matches with respect to Jaccard index
	k = len(next(iter(k_gram_index.keys())))
	
	word = f"${word}$"
	kgrams = set(k_grams(word, k))
	results = set()
	
	for kgram in kgrams:
		options = k_gram_index[kgram]

		for option in options:
			score = iou(kgrams, option)
			if score > 0.1:
				results.add((option, score))
	
	results = sorted(results, key=lambda x: x[1], reverse=True)
	results = list(option for option, _ in results)

	return results

# %%
grams = set(k_grams("$enough$", 3))

# %%
k_gram_index_github["$uh"]
# Out:
# {'uh', 'uhm', 'uhyve'}

# %%
iou(grams, "uh")
# Out:
# 0.0

# %%
fix_typo_kgram("red", k_gram_index_github)[:10]
# Out:
# ['red',
#  'fred',
#  'reda',
#  'cred',
#  'redo',
#  'pred',
#  'wired',
#  'fired',
#  'shred',
#  'bored']

# %% [markdown]
# ### 1.2.2. Tests

# %%
# tests

k_gram_index_github = build_k_gram_index(vocabulary, 3)
print(fix_typo_kgram("enouh", k_gram_index_github)[:20])
assert "enough" in fix_typo_kgram("enouh", k_gram_index_github), "Assert k-gram failed"
# Out:
# ['enough', 'enought', 'renounce', 'exogenous', 'eno', 'homogenous', 'endogenous', 'nous', 'hetrogenous', 'deno', 'noun', 'heterogenous', 'snout', 'inout', 'nouns', 'menoh', 'fenom', 'runout', 'renown', 'zenodo']

# %% [markdown]
# ## 1.3. [Extra tasks, for fun]
#
# ### 1.3.1. QWERTY - Editorial distance
#
# Write the code to compute weighted QWERTY-editorial distance.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/KB_United_States.svg/640px-KB_United_States.svg.png" width="640"/>
#
# Use this image to prepare weight function:
# - all letter pairs which share vertical border will get 0.5 multiplier **for replace** (`df`, `cv`, `ui`, ...)
# - all letter pairs which share at least some horizontal border will get 0.7 multiplier **for replace** (`dc`, `dr`, `km`, ...)
# - other operations are not scaled (x1 multiplier).

# %%
def replace_weight(let1, let2) -> float:
	# TODO what is the weight for a pair of letters being replaced? 
	# Note this function should be commutative

	return 0.0


def qwerty_edit_dist(s1, s2) -> float:
	# TODO compute the Damerau-Levenshtein distance 
	# between two given strings (s1 and s2)

	return 0.0

# %%
# tests

assert qwerty_edit_dist("korrectud", "corrected") == 2.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("soem", "some") == 1.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("one", "one") == 0.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("fihure", "figure") == 0.5, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("fivure", "figure") == 0.7, "Edit distance is computed incorrectly"

# %% [markdown]
# ### 1.3.2. Norvig's spellchecker with QWERTY weights
#
# You can base your code on [Norvig's corrector](https://norvig.com/spell-correct.html), but you should be sure you account the fact, that typos for close letters cost less. This should be considered in ranking.

# %%
def fix_typo_qwerty_norvig(word) -> str:
	#TODO return best matching result for the word

	return ""

# %%
# tests

assert fix_typo_qwerty_norvig("korrectud") == "corrected", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("speling") == "spelling", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("condidence") == "confidence", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("fpx") == "fox", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("fux") == "fix", "Norvig's correcter doesn't work"

# %% [markdown]
# ### 12.3.3. Estimate quality of functions

# %%
norvig, kgram = 0, 0
limit = 10000
counter = limit
for i, (src, target) in enumerate(dataset):
	if i == limit:
		break
	words = sent_to_words(src.lower())
	# word suspected for typos
	sn, sk = src.lower(), src.lower()
	for word in words:
		if word not in vocabulary and word.isalpha():
			# top-1 accuracy
			wn, wk = fix_typo_qwerty_norvig(word), \
				fix_typo_kgram(word, k_gram_index_github)[0]
			sn = sn.replace(word, wn)
			sk = sk.replace(word, wk)
	norvig += int(sn == target.lower())
	kgram += int(sk == target.lower())

print(f"Norvig accuracy ({norvig}) = {norvig / limit}")
print(f"k-gram accuracy ({kgram}) = {kgram / limit}")
